# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import re
import pandas as pd
import urllib
import time
import numpy as np

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# %%
def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

# %%
def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
def getPron(word):
    ods = False #marker for if DOS was used instead of DDS
    print(word)
    if ' ' in word:
        print('had space')
        time.sleep(.300)
        return(np.nan)
    page = getPage(word)
    if page is None:
        print('no page, trying ODS')
        page = simple_get('https://ordnet.dk/ods/ordbog?query=' + urllib.parse.quote(word)) # look in ODS
        ods = True
        if page is None: # if it's still none, return na
            print('no page at all')
            time.sleep(.300)
            return(np.nan)
    page = BeautifulSoup(page)
    page = page.find_all("span", {"class":"lydskrift"})
    if not page:        
        print('no pron in ODD, trying ODS')
        page = simple_get('https://ordnet.dk/ods/ordbog?query=' + urllib.parse.quote(word)) # look in ODS        
        if page is None:
            time.sleep(.300)
            print('no pron data either in ODD or ODS')
            return(np.nan)
        page = BeautifulSoup(page)
        page = page.find_all("span", {'class': 'lydskrift'})
        if not page:
            print('no pron data either in ODD or ODS')
            time.sleep(.300)
            return(np.nan)
        ods = True
    page = page[0]
    rawPron = str(page.get_text())
    time.sleep(.300)
    pron = parseRaw(rawPron)
    if ods:
        pron = str(pron) + "(ods)" # add marker to remember which ones were from the historical dictionary
    print(pron)
    print('------------------------------------------------------')
    return(pron)

# %%
def getPage(word):
    urlWord = urllib.parse.quote(word)
    completeURL = 'https://ordnet.dk/ddo/ordbog?query=' + urllib.parse.quote(word)
    print(completeURL)
    return(simple_get(completeURL))

# %%
def parseRaw(rawString):
    pattern = re.compile("(?<=\[).+(?=\])")
    pronunciation = pattern.search(rawString)
    if pronunciation is None: # no matches
        return(np.nan)
    return(pronunciation.group(0))

# %% [markdown]
# # First stage

# %%
danishWords = pd.read_csv('wordsforg2p/manual/danishmanual.csv')

# %%
danishProns = [getPron(word) for word in list(danishWords['Orth'])] #still have to debug (timeout?????)
# some are marked as not having but they have it. probably timed out and getting kicked out of the site. run second round of scraping for words marked as nan.
# Out:
# ofte
# https://ordnet.dk/ddo/ordbog?query=ofte
# ˈʌfdə
# ------------------------------------------------------
# tit
# https://ordnet.dk/ddo/ordbog?query=tit
# ˈtid
# ------------------------------------------------------
# altid
# https://ordnet.dk/ddo/ordbog?query=altid
# ˈalˀˌtiðˀ
# ------------------------------------------------------
# færdig
# https://ordnet.dk/ddo/ordbog?query=f%C3%A6rdig
# ˈfæɐ̯di
# ------------------------------------------------------
# ophøre
# https://ordnet.dk/ddo/ordbog?query=oph%C3%B8re
# ˈʌbˌhøˀʌ
# ------------------------------------------------------
# ende
# https://ordnet.dk/ddo/ordbog?query=ende
# ˈεnə
# ------------------------------------------------------
# slutte
# https://ordnet.dk/ddo/ordbog?query=slutte
# ˈsludə
# ------------------------------------------------------
# af-slutte
# https://ordnet.dk/ddo/ordbog?query=af-slutte
# ˈɑwˌsludə
# ------------------------------------------------------
# ende
# https://ordnet.dk/ddo/ordbog?query=ende
# ˈεnə
# ------------------------------------------------------
# slutning
# https://ordnet.dk/ddo/ordbog?query=slutning
# ˈsludneŋ
# ------------------------------------------------------
# vare
# https://ordnet.dk/ddo/ordbog?query=vare
# ˈvɑːɑ
# ------------------------------------------------------
# begynde
# https://ordnet.dk/ddo/ordbog?query=begynde
# beˈgønˀə
# ------------------------------------------------------
# begyndelse
# https://ordnet.dk/ddo/ordbog?query=begyndelse
# beˈgønˀəlsə
# ------------------------------------------------------
# forsinke
# https://ordnet.dk/ddo/ordbog?query=forsinke
# fʌˈseŋˀgə
# ------------------------------------------------------
# skynde sig
# had space
# haste
# https://ordnet.dk/ddo/ordbog?query=haste
# ˈhasdə
# ------------------------------------------------------
# ile
# https://ordnet.dk/ddo/ordbog?query=ile
# ˈiːlə
# ------------------------------------------------------
# langsom
# https://ordnet.dk/ddo/ordbog?query=langsom
# ˈlɑŋˌsʌmˀ
# ------------------------------------------------------
# hurtig
# https://ordnet.dk/ddo/ordbog?query=hurtig
# ˈhoɐ̯di
# ------------------------------------------------------
# straks
# https://ordnet.dk/ddo/ordbog?query=straks
# ˈsdʁɑgs
# ------------------------------------------------------
# nu
# https://ordnet.dk/ddo/ordbog?query=nu
# ˈnu
# ------------------------------------------------------
# sent
# https://ordnet.dk/ddo/ordbog?query=sent
# ˈseˀn
# ------------------------------------------------------
# tidlig
# https://ordnet.dk/ddo/ordbog?query=tidlig
# ˈtiðli
# ------------------------------------------------------
# gammel
# https://ordnet.dk/ddo/ordbog?query=gammel
# ˈgɑməl
# ------------------------------------------------------
# ung
# https://ordnet.dk/ddo/ordbog?query=ung
# ˈɔŋˀ
# ------------------------------------------------------
# alder
# https://ordnet.dk/ddo/ordbog?query=alder
# ˈalˀʌ
# ------------------------------------------------------
# ny
# https://ordnet.dk/ddo/ordbog?query=ny
# ˈnyˀ
# ------------------------------------------------------
# tid
# https://ordnet.dk/ddo/ordbog?query=tid
# ˈtiðˀ
# ------------------------------------------------------
# tre gange
# had space
# tredje
# https://ordnet.dk/ddo/ordbog?query=tredje
# ˈtʁεðjə
# ------------------------------------------------------
# to gange
# had space
# par
# https://ordnet.dk/ddo/ordbog?query=par
# no pron in ODD, trying ODS
# nan(ods)
# ------------------------------------------------------
# anden
# https://ordnet.dk/ddo/ordbog?query=anden
# ˈanən
# ------------------------------------------------------
# sidst
# https://ordnet.dk/ddo/ordbog?query=sidst
# ˈsisd
# ------------------------------------------------------
# først
# https://ordnet.dk/ddo/ordbog?query=f%C3%B8rst
# ˈfɶɐ̯sd
# ------------------------------------------------------
# alene
# https://ordnet.dk/ddo/ordbog?query=alene
# aˈleːnə
# ------------------------------------------------------
# eneste
# https://ordnet.dk/ddo/ordbog?query=eneste
# ˈeːnəsdə
# ------------------------------------------------------
# kun
# https://ordnet.dk/ddo/ordbog?query=kun
# ˈkɔn
# ------------------------------------------------------
# blot
# https://ordnet.dk/ddo/ordbog?query=blot
# ˈbloˀd
# ------------------------------------------------------
# halv
# https://ordnet.dk/ddo/ordbog?query=halv
# ˈhalˀ
# ------------------------------------------------------
# del
# https://ordnet.dk/ddo/ordbog?query=del
# ˈdeˀl
# ------------------------------------------------------
# tom
# https://ordnet.dk/ddo/ordbog?query=tom
# ˈtʌmˀ
# ------------------------------------------------------
# fuld
# https://ordnet.dk/ddo/ordbog?query=fuld
# ˈfulˀ
# ------------------------------------------------------
# mængde
# https://ordnet.dk/ddo/ordbog?query=m%C3%A6ngde
# ˈmεŋˀdə
# ------------------------------------------------------
# noget
# https://ordnet.dk/ddo/ordbog?query=noget
# ˈnoən
# ------------------------------------------------------
# lidt
# https://ordnet.dk/ddo/ordbog?query=lidt
# ˈlid
# ------------------------------------------------------
# få
# https://ordnet.dk/ddo/ordbog?query=fa%CC%8A
# no page, trying ODS
# no page at all
# nok
# https://ordnet.dk/ddo/ordbog?query=nok
# ˈnʌg
# ------------------------------------------------------
# mer
# https://ordnet.dk/ddo/ordbog?query=mer
# ˈmeːʌ
# ------------------------------------------------------
# flere
# https://ordnet.dk/ddo/ordbog?query=flere
# ˈfleːʌ
# ------------------------------------------------------
# megen
# https://ordnet.dk/ddo/ordbog?query=megen
# ˈmɑjən
# ------------------------------------------------------
# mange
# https://ordnet.dk/ddo/ordbog?query=mange
# ˈmɑŋən
# ------------------------------------------------------
# hver
# https://ordnet.dk/ddo/ordbog?query=hver
# ˈvεˀɐ̯
# ------------------------------------------------------
# en-hver
# https://ordnet.dk/ddo/ordbog?query=en-hver
# enˈvεɐ̯ˀ
# ------------------------------------------------------
# al
# https://ordnet.dk/ddo/ordbog?query=al
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# alle
# https://ordnet.dk/ddo/ordbog?query=alle
# aˈleˀ
# ------------------------------------------------------
# tælle
# https://ordnet.dk/ddo/ordbog?query=t%C3%A6lle
# ˈtεlə
# ------------------------------------------------------
# tusinde
# https://ordnet.dk/ddo/ordbog?query=tusinde
# ˈtuˀsən
# ------------------------------------------------------
# hundrede
# https://ordnet.dk/ddo/ordbog?query=hundrede
# ˈhunʌðə
# ------------------------------------------------------
# tyve
# https://ordnet.dk/ddo/ordbog?query=tyve
# ˈtyːvə
# ------------------------------------------------------
# femten
# https://ordnet.dk/ddo/ordbog?query=femten
# ˈfεmdən
# ------------------------------------------------------
# tolv
# https://ordnet.dk/ddo/ordbog?query=tolv
# ˈtʌlˀ
# ------------------------------------------------------
# elleve
# https://ordnet.dk/ddo/ordbog?query=elleve
# ˈεlvə
# ------------------------------------------------------
# ti
# https://ordnet.dk/ddo/ordbog?query=ti
# ˈtiˀ
# ------------------------------------------------------
# ni
# https://ordnet.dk/ddo/ordbog?query=ni
# ˈniˀ
# ------------------------------------------------------
# otte
# https://ordnet.dk/ddo/ordbog?query=otte
# ˈɔːdə
# ------------------------------------------------------
# syv
# https://ordnet.dk/ddo/ordbog?query=syv
# ˈsywˀ
# ------------------------------------------------------
# seks
# https://ordnet.dk/ddo/ordbog?query=seks
# ˈsεgs
# ------------------------------------------------------
# fem
# https://ordnet.dk/ddo/ordbog?query=fem
# ˈfεmˀ
# ------------------------------------------------------
# fire
# https://ordnet.dk/ddo/ordbog?query=fire
# ˈfiːʌ
# ------------------------------------------------------
# to
# https://ordnet.dk/ddo/ordbog?query=to
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# tre
# https://ordnet.dk/ddo/ordbog?query=tre
# ˈtʁεˀ
# ------------------------------------------------------
# een
# https://ordnet.dk/ddo/ordbog?query=een
# ˈeˀn
# ------------------------------------------------------
# nul
# https://ordnet.dk/ddo/ordbog?query=nul
# ˈnɔl
# ------------------------------------------------------
# ingenting
# https://ordnet.dk/ddo/ordbog?query=ingenting
# ˈeŋənˈteŋˀ
# ------------------------------------------------------
# forandre
# https://ordnet.dk/ddo/ordbog?query=forandre
# fʌˈɑnˀdʁʌ
# ------------------------------------------------------
# skifte
# https://ordnet.dk/ddo/ordbog?query=skifte
# ˈsgifdə
# ------------------------------------------------------
# veksle
# https://ordnet.dk/ddo/ordbog?query=veksle
# ˈvεgslə
# ------------------------------------------------------
# lignende
# https://ordnet.dk/ddo/ordbog?query=lignende
# ˈliːnənə
# ------------------------------------------------------
# lige
# https://ordnet.dk/ddo/ordbog?query=lige
# ˈliːə
# ------------------------------------------------------
# linie
# https://ordnet.dk/ddo/ordbog?query=linie
# ˈlinjə
# ------------------------------------------------------
# hul
# https://ordnet.dk/ddo/ordbog?query=hul
# ˈhɔl
# ------------------------------------------------------
# klode
# https://ordnet.dk/ddo/ordbog?query=klode
# ˈkloːðə
# ------------------------------------------------------
# kugle
# https://ordnet.dk/ddo/ordbog?query=kugle
# ˈkuːlə
# ------------------------------------------------------
# rund
# https://ordnet.dk/ddo/ordbog?query=rund
# ˈʁɔnˀ
# ------------------------------------------------------
# kreds
# https://ordnet.dk/ddo/ordbog?query=kreds
# ˈkʁεˀs
# ------------------------------------------------------
# firkant
# https://ordnet.dk/ddo/ordbog?query=firkant
# ˈfiɐ̯-
# ------------------------------------------------------
# kors
# https://ordnet.dk/ddo/ordbog?query=kors
# ˈkɒːs
# ------------------------------------------------------
# kryds
# https://ordnet.dk/ddo/ordbog?query=kryds
# ˈkʁys
# ------------------------------------------------------
# hjørne
# https://ordnet.dk/ddo/ordbog?query=hj%C3%B8rne
# ˈjɶɐ̯nə
# ------------------------------------------------------
# krog
# https://ordnet.dk/ddo/ordbog?query=krog
# ˈkʁɔˀw
# ------------------------------------------------------
# hage
# https://ordnet.dk/ddo/ordbog?query=hage
# ˈhæːjə
# ------------------------------------------------------
# krum
# https://ordnet.dk/ddo/ordbog?query=krum
# ˈkʁɔmˀ
# ------------------------------------------------------
# kroget
# https://ordnet.dk/ddo/ordbog?query=kroget
# ˈkʁɔːwəð
# ------------------------------------------------------
# lige
# https://ordnet.dk/ddo/ordbog?query=lige
# ˈliːə
# ------------------------------------------------------
# ret
# https://ordnet.dk/ddo/ordbog?query=ret
# ˈʁad
# ------------------------------------------------------
# flad
# https://ordnet.dk/ddo/ordbog?query=flad
# ˈflæˀð
# ------------------------------------------------------
# grund
# https://ordnet.dk/ddo/ordbog?query=grund
# ˈgʁɔnˀ
# ------------------------------------------------------
# dyb
# https://ordnet.dk/ddo/ordbog?query=dyb
# ˈdyˀb
# ------------------------------------------------------
# tynd
# https://ordnet.dk/ddo/ordbog?query=tynd
# ˈtønˀ
# ------------------------------------------------------
# tyk
# https://ordnet.dk/ddo/ordbog?query=tyk
# ˈtyg
# ------------------------------------------------------
# snæver
# https://ordnet.dk/ddo/ordbog?query=sn%C3%A6ver
# ˈsnεwˀʌ
# ------------------------------------------------------
# smal
# https://ordnet.dk/ddo/ordbog?query=smal
# ˈsmalˀ
# ------------------------------------------------------
# bred
# https://ordnet.dk/ddo/ordbog?query=bred
# ˈbʁεðˀ
# ------------------------------------------------------
# vid
# https://ordnet.dk/ddo/ordbog?query=vid
# ˈvið
# ------------------------------------------------------
# kort
# https://ordnet.dk/ddo/ordbog?query=kort
# ˈkɒːd
# ------------------------------------------------------
# stor
# https://ordnet.dk/ddo/ordbog?query=stor
# ˈsdoˀɐ̯
# ------------------------------------------------------
# høj
# https://ordnet.dk/ddo/ordbog?query=h%C3%B8j
# ˈhʌjˀ
# ------------------------------------------------------
# lang
# https://ordnet.dk/ddo/ordbog?query=lang
# ˈlɑŋˀ
# ------------------------------------------------------
# lille
# https://ordnet.dk/ddo/ordbog?query=lille
# ˈlilə
# ------------------------------------------------------
# små
# https://ordnet.dk/ddo/ordbog?query=sma%CC%8A
# no page, trying ODS
# no page at all
# stor
# https://ordnet.dk/ddo/ordbog?query=stor
# ˈsdoˀɐ̯
# ------------------------------------------------------
# favn
# https://ordnet.dk/ddo/ordbog?query=favn
# ˈfɑwˀn
# ------------------------------------------------------
# måle
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Ale
# no page, trying ODS
# no page at all
# vokse
# https://ordnet.dk/ddo/ordbog?query=vokse
# ˈvʌgsə
# ------------------------------------------------------
# syd
# https://ordnet.dk/ddo/ordbog?query=syd
# ˈsyð
# ------------------------------------------------------
# nord
# https://ordnet.dk/ddo/ordbog?query=nord
# ˈnoˀɐ̯
# ------------------------------------------------------
# vest
# https://ordnet.dk/ddo/ordbog?query=vest
# ˈvεsd
# ------------------------------------------------------
# øst
# https://ordnet.dk/ddo/ordbog?query=%C3%B8st
# ˈøsd
# ------------------------------------------------------
# nær
# https://ordnet.dk/ddo/ordbog?query=n%C3%A6r
# ˈnεˀɐ̯
# ------------------------------------------------------
# langt
# https://ordnet.dk/ddo/ordbog?query=langt
# ˈlɑŋˀ
# ------------------------------------------------------
# fjernt
# https://ordnet.dk/ddo/ordbog?query=fjernt
# ˈfjæɐ̯ˀn
# ------------------------------------------------------
# venstre
# https://ordnet.dk/ddo/ordbog?query=venstre
# ˈvεnsdʁʌ
# ------------------------------------------------------
# højre
# https://ordnet.dk/ddo/ordbog?query=h%C3%B8jre
# ˈhʌjʁʌ
# ------------------------------------------------------
# midterst
# https://ordnet.dk/ddo/ordbog?query=midterst
# ˈmedʌsd
# ------------------------------------------------------
# mellemst
# https://ordnet.dk/ddo/ordbog?query=mellemst
# ˈmεlˀəmsd
# ------------------------------------------------------
# midte
# https://ordnet.dk/ddo/ordbog?query=midte
# ˈmedə
# ------------------------------------------------------
# side
# https://ordnet.dk/ddo/ordbog?query=side
# ˈsiːðə
# ------------------------------------------------------
# kant
# https://ordnet.dk/ddo/ordbog?query=kant
# ˈkanˀd
# ------------------------------------------------------
# rand
# https://ordnet.dk/ddo/ordbog?query=rand
# ˈʁɑnˀ
# ------------------------------------------------------
# spids
# https://ordnet.dk/ddo/ordbog?query=spids
# ˈsbes
# ------------------------------------------------------
# ende
# https://ordnet.dk/ddo/ordbog?query=ende
# ˈεnə
# ------------------------------------------------------
# bund
# https://ordnet.dk/ddo/ordbog?query=bund
# ˈbɔnˀ
# ------------------------------------------------------
# lav
# https://ordnet.dk/ddo/ordbog?query=lav
# ˈlɑw
# ------------------------------------------------------
# top
# https://ordnet.dk/ddo/ordbog?query=top
# ˈtʌb
# ------------------------------------------------------
# spids
# https://ordnet.dk/ddo/ordbog?query=spids
# ˈsbes
# ------------------------------------------------------
# høj
# https://ordnet.dk/ddo/ordbog?query=h%C3%B8j
# ˈhʌjˀ
# ------------------------------------------------------
# skjule
# https://ordnet.dk/ddo/ordbog?query=skjule
# ˈsgjuːlə
# ------------------------------------------------------
# gemme
# https://ordnet.dk/ddo/ordbog?query=gemme
# ˈgεmə
# ------------------------------------------------------
# lukke
# https://ordnet.dk/ddo/ordbog?query=lukke
# ˈlɔgə
# ------------------------------------------------------
# til-lukke
# https://ordnet.dk/ddo/ordbog?query=til-lukke
# nan
# ------------------------------------------------------
# dække
# https://ordnet.dk/ddo/ordbog?query=d%C3%A6kke
# ˈdεgə
# ------------------------------------------------------
# åbne
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Abne
# no page, trying ODS
# no page at all
# lukke op
# had space
# dele
# https://ordnet.dk/ddo/ordbog?query=dele
# ˈdeːlə
# ------------------------------------------------------
# skille
# https://ordnet.dk/ddo/ordbog?query=skille
# ˈsgelə
# ------------------------------------------------------
# ad-skille
# https://ordnet.dk/ddo/ordbog?query=ad-skille
# ˈaðˌsgelˀə
# ------------------------------------------------------
# forbinde
# https://ordnet.dk/ddo/ordbog?query=forbinde
# fʌˈbenˀə
# ------------------------------------------------------
# forene
# https://ordnet.dk/ddo/ordbog?query=forene
# fʌˈeˀnə
# ------------------------------------------------------
# hobe op
# had space
# samle op
# had space
# samle
# https://ordnet.dk/ddo/ordbog?query=samle
# ˈsɑmlə
# ------------------------------------------------------
# rester
# https://ordnet.dk/ddo/ordbog?query=rester
# ˈʁasd
# ------------------------------------------------------
# blive
# https://ordnet.dk/ddo/ordbog?query=blive
# ˈbliːə
# ------------------------------------------------------
# stå
# https://ordnet.dk/ddo/ordbog?query=sta%CC%8A
# no page, trying ODS
# no page at all
# ligge
# https://ordnet.dk/ddo/ordbog?query=ligge
# ˈlegə
# ------------------------------------------------------
# sidde
# https://ordnet.dk/ddo/ordbog?query=sidde
# ˈseðə
# ------------------------------------------------------
# sætte
# https://ordnet.dk/ddo/ordbog?query=s%C3%A6tte
# ˈsεdə
# ------------------------------------------------------
# stille
# https://ordnet.dk/ddo/ordbog?query=stille
# ˈsdelə
# ------------------------------------------------------
# lægge
# https://ordnet.dk/ddo/ordbog?query=l%C3%A6gge
# ˈlεgə
# ------------------------------------------------------
# plads
# https://ordnet.dk/ddo/ordbog?query=plads
# ˈplas
# ------------------------------------------------------
# sted
# https://ordnet.dk/ddo/ordbog?query=sted
# ˈsdεð
# ------------------------------------------------------
# oppe
# https://ordnet.dk/ddo/ordbog?query=oppe
# ˈʌbə
# ------------------------------------------------------
# ovenpå
# https://ordnet.dk/ddo/ordbog?query=ovenpa%CC%8A
# no page, trying ODS
# no page at all
# under
# https://ordnet.dk/ddo/ordbog?query=under
# ˈɔnˀʌ
# ------------------------------------------------------
# ude
# https://ordnet.dk/ddo/ordbog?query=ude
# ˈuːðə
# ------------------------------------------------------
# inde
# https://ordnet.dk/ddo/ordbog?query=inde
# ˈenə
# ------------------------------------------------------
# for
# https://ordnet.dk/ddo/ordbog?query=for
# ˈfoˀɐ̯
# ------------------------------------------------------
# før
# https://ordnet.dk/ddo/ordbog?query=f%C3%B8r
# ˈføˀɐ̯
# ------------------------------------------------------
# nede
# https://ordnet.dk/ddo/ordbog?query=nede
# ˈneːðə
# ------------------------------------------------------
# ved siden af
# had space
# bag
# https://ordnet.dk/ddo/ordbog?query=bag
# ˈbæˀj
# ------------------------------------------------------
# efter
# https://ordnet.dk/ddo/ordbog?query=efter
# ˈεfdʌ
# ------------------------------------------------------
# veje
# https://ordnet.dk/ddo/ordbog?query=veje
# ˈvɑjə
# ------------------------------------------------------
# dele med
# had space
# billig
# https://ordnet.dk/ddo/ordbog?query=billig
# ˈbili
# ------------------------------------------------------
# dyr
# https://ordnet.dk/ddo/ordbog?query=dyr
# ˈdyɐ̯ˀ
# ------------------------------------------------------
# pris
# https://ordnet.dk/ddo/ordbog?query=pris
# ˈpʁiˀs
# ------------------------------------------------------
# butik
# https://ordnet.dk/ddo/ordbog?query=butik
# buˈtig
# ------------------------------------------------------
# forretning
# https://ordnet.dk/ddo/ordbog?query=forretning
# fʌˈʁadneŋ
# ------------------------------------------------------
# torv
# https://ordnet.dk/ddo/ordbog?query=torv
# ˈtɒˀw
# ------------------------------------------------------
# marked
# https://ordnet.dk/ddo/ordbog?query=marked
# ˈmɑːgəð
# ------------------------------------------------------
# købmand
# https://ordnet.dk/ddo/ordbog?query=k%C3%B8bmand
# ˈkøˌmanˀ
# ------------------------------------------------------
# handle
# https://ordnet.dk/ddo/ordbog?query=handle
# ˈhanlə
# ------------------------------------------------------
# sælge
# https://ordnet.dk/ddo/ordbog?query=s%C3%A6lge
# ˈsεljə
# ------------------------------------------------------
# købe
# https://ordnet.dk/ddo/ordbog?query=k%C3%B8be
# ˈkøːbə
# ------------------------------------------------------
# tjene
# https://ordnet.dk/ddo/ordbog?query=tjene
# ˈtjεːnə
# ------------------------------------------------------
# løn
# https://ordnet.dk/ddo/ordbog?query=l%C3%B8n
# ˈlœnˀ
# ------------------------------------------------------
# betaling
# https://ordnet.dk/ddo/ordbog?query=betaling
# beˈtæˀleŋ
# ------------------------------------------------------
# hyre
# https://ordnet.dk/ddo/ordbog?query=hyre
# ˈhyːʌ
# ------------------------------------------------------
# skat
# https://ordnet.dk/ddo/ordbog?query=skat
# ˈsgad
# ------------------------------------------------------
# regnskab
# https://ordnet.dk/ddo/ordbog?query=regnskab
# ˈʁɑjnˌsgæˀb
# ------------------------------------------------------
# regning
# https://ordnet.dk/ddo/ordbog?query=regning
# ˈʁɑjneŋ
# ------------------------------------------------------
# betale
# https://ordnet.dk/ddo/ordbog?query=betale
# beˈtæˀlə
# ------------------------------------------------------
# gæld
# https://ordnet.dk/ddo/ordbog?query=g%C3%A6ld
# ˈgεlˀ
# ------------------------------------------------------
# skylde
# https://ordnet.dk/ddo/ordbog?query=skylde
# ˈsgylə
# ------------------------------------------------------
# låne
# https://ordnet.dk/ddo/ordbog?query=la%CC%8Ane
# no page, trying ODS
# no page at all
# låne
# https://ordnet.dk/ddo/ordbog?query=la%CC%8Ane
# no page, trying ODS
# no page at all
# gerrig
# https://ordnet.dk/ddo/ordbog?query=gerrig
# ˈgæɐ̯i
# ------------------------------------------------------
# tigger
# https://ordnet.dk/ddo/ordbog?query=tigger
# ˈtegʌ
# ------------------------------------------------------
# fattig
# https://ordnet.dk/ddo/ordbog?query=fattig
# ˈfadi
# ------------------------------------------------------
# rig
# https://ordnet.dk/ddo/ordbog?query=rig
# ˈʁεg
# ------------------------------------------------------
# mønt
# https://ordnet.dk/ddo/ordbog?query=m%C3%B8nt
# ˈmønˀd
# ------------------------------------------------------
# penge
# https://ordnet.dk/ddo/ordbog?query=penge
# ˈpεŋə
# ------------------------------------------------------
# løslade
# https://ordnet.dk/ddo/ordbog?query=l%C3%B8slade
# -ˌlæˀðə
# ------------------------------------------------------
# slippe løs
# had space
# tabe
# https://ordnet.dk/ddo/ordbog?query=tabe
# ˈtæːbə
# ------------------------------------------------------
# finde
# https://ordnet.dk/ddo/ordbog?query=finde
# ˈfenə
# ------------------------------------------------------
# hitte
# https://ordnet.dk/ddo/ordbog?query=hitte
# ˈhidə
# ------------------------------------------------------
# søge
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8ge
# ˈsøːjə
# ------------------------------------------------------
# lede efter
# had space
# skade
# https://ordnet.dk/ddo/ordbog?query=skade
# ˈsgæːðə
# ------------------------------------------------------
# beskadige
# https://ordnet.dk/ddo/ordbog?query=beskadige
# beˈsgæˀˌðiˀə
# ------------------------------------------------------
# ødelægge
# https://ordnet.dk/ddo/ordbog?query=%C3%B8del%C3%A6gge
# ˈøːðəˌlεgə
# ------------------------------------------------------
# redde
# https://ordnet.dk/ddo/ordbog?query=redde
# ˈʁεðə
# ------------------------------------------------------
# frelse
# https://ordnet.dk/ddo/ordbog?query=frelse
# ˈfʁalsə
# ------------------------------------------------------
# bevare
# https://ordnet.dk/ddo/ordbog?query=bevare
# beˈvɑˀɑ
# ------------------------------------------------------
# passe på
# had space
# give tilbage
# had space
# give
# https://ordnet.dk/ddo/ordbog?query=give
# ˈgiˀ
# ------------------------------------------------------
# ting
# https://ordnet.dk/ddo/ordbog?query=ting
# ˈteŋˀ
# ------------------------------------------------------
# beholde
# https://ordnet.dk/ddo/ordbog?query=beholde
# beˈhʌlˀə
# ------------------------------------------------------
# få
# https://ordnet.dk/ddo/ordbog?query=fa%CC%8A
# no page, trying ODS
# no page at all
# holde
# https://ordnet.dk/ddo/ordbog?query=holde
# ˈhʌlə
# ------------------------------------------------------
# gribe
# https://ordnet.dk/ddo/ordbog?query=gribe
# ˈgʁiːbə
# ------------------------------------------------------
# tage
# https://ordnet.dk/ddo/ordbog?query=tage
# ˈtæˀ
# ------------------------------------------------------
# eje
# https://ordnet.dk/ddo/ordbog?query=eje
# ˈɑjə
# ------------------------------------------------------
# besidde
# https://ordnet.dk/ddo/ordbog?query=besidde
# beˈsiðˀə
# ------------------------------------------------------
# have
# https://ordnet.dk/ddo/ordbog?query=have
# ˈhæːvə
# ------------------------------------------------------
# lande
# https://ordnet.dk/ddo/ordbog?query=lande
# ˈlanə
# ------------------------------------------------------
# havn
# https://ordnet.dk/ddo/ordbog?query=havn
# ˈhɑwˀn
# ------------------------------------------------------
# anker
# https://ordnet.dk/ddo/ordbog?query=anker
# ˈɑŋgʌ
# ------------------------------------------------------
# sejl
# https://ordnet.dk/ddo/ordbog?query=sejl
# ˈsɑjˀl
# ------------------------------------------------------
# mast
# https://ordnet.dk/ddo/ordbog?query=mast
# ˈmasd
# ------------------------------------------------------
# styr
# https://ordnet.dk/ddo/ordbog?query=styr
# ˈsdyɐ̯ˀ
# ------------------------------------------------------
# ror
# https://ordnet.dk/ddo/ordbog?query=ror
# ˈʁoˀɐ̯
# ------------------------------------------------------
# ro
# https://ordnet.dk/ddo/ordbog?query=ro
# ˈʁoˀ
# ------------------------------------------------------
# pagaj
# https://ordnet.dk/ddo/ordbog?query=pagaj
# paˈgɑjˀ
# ------------------------------------------------------
# åre
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Are
# no page, trying ODS
# no page at all
# flåde
# https://ordnet.dk/ddo/ordbog?query=fla%CC%8Ade
# no page, trying ODS
# no page at all
# udlægger
# https://ordnet.dk/ddo/ordbog?query=udl%C3%A6gger
# nan
# ------------------------------------------------------
# kano
# https://ordnet.dk/ddo/ordbog?query=kano
# ˈkæːno
# ------------------------------------------------------
# båd
# https://ordnet.dk/ddo/ordbog?query=ba%CC%8Ad
# no page, trying ODS
# no page at all
# skib
# https://ordnet.dk/ddo/ordbog?query=skib
# ˈsgiˀb
# ------------------------------------------------------
# åg
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Ag
# no page, trying ODS
# no page at all
# aksel
# https://ordnet.dk/ddo/ordbog?query=aksel
# ˈɑgsəl
# ------------------------------------------------------
# hjul
# https://ordnet.dk/ddo/ordbog?query=hjul
# ˈjuˀl
# ------------------------------------------------------
# vogn
# https://ordnet.dk/ddo/ordbog?query=vogn
# ˈvɒwˀn
# ------------------------------------------------------
# bro
# https://ordnet.dk/ddo/ordbog?query=bro
# ˈbʁoˀ
# ------------------------------------------------------
# sti
# https://ordnet.dk/ddo/ordbog?query=sti
# ˈsdiˀ
# ------------------------------------------------------
# vej
# https://ordnet.dk/ddo/ordbog?query=vej
# ˈvɑjˀ
# ------------------------------------------------------
# skubbe
# https://ordnet.dk/ddo/ordbog?query=skubbe
# ˈsgɔbə
# ------------------------------------------------------
# støde
# https://ordnet.dk/ddo/ordbog?query=st%C3%B8de
# ˈsdøːðə
# ------------------------------------------------------
# ride
# https://ordnet.dk/ddo/ordbog?query=ride
# ˈʁiːðə
# ------------------------------------------------------
# drive
# https://ordnet.dk/ddo/ordbog?query=drive
# ˈdʁiːvə
# ------------------------------------------------------
# lede
# https://ordnet.dk/ddo/ordbog?query=lede
# ˈleːðə
# ------------------------------------------------------
# føre
# https://ordnet.dk/ddo/ordbog?query=f%C3%B8re
# ˈføːʌ
# ------------------------------------------------------
# sende
# https://ordnet.dk/ddo/ordbog?query=sende
# ˈsεnə
# ------------------------------------------------------
# bringe
# https://ordnet.dk/ddo/ordbog?query=bringe
# ˈbʁεŋə
# ------------------------------------------------------
# bære under armen
# had space
# bære på hovedet
# had space
# bære på skulderen
# had space
# bære i hånden
# had space
# bære
# https://ordnet.dk/ddo/ordbog?query=b%C3%A6re
# ˈbεːʌ
# ------------------------------------------------------
# indtræde
# https://ordnet.dk/ddo/ordbog?query=indtr%C3%A6de
# -ˌtʁεˀðə
# ------------------------------------------------------
# nærme sig
# had space
# ankomme
# https://ordnet.dk/ddo/ordbog?query=ankomme
# ˈanˌkʌmˀə
# ------------------------------------------------------
# nå
# https://ordnet.dk/ddo/ordbog?query=na%CC%8A
# no page, trying ODS
# no page at all
# forfølge
# https://ordnet.dk/ddo/ordbog?query=forf%C3%B8lge
# fʌˈfølˀjə
# ------------------------------------------------------
# følge
# https://ordnet.dk/ddo/ordbog?query=f%C3%B8lge
# ˈføljə
# ------------------------------------------------------
# flygte
# https://ordnet.dk/ddo/ordbog?query=flygte
# ˈfløgdə
# ------------------------------------------------------
# fly
# https://ordnet.dk/ddo/ordbog?query=fly
# ˈflyˀ
# ------------------------------------------------------
# forsvinde
# https://ordnet.dk/ddo/ordbog?query=forsvinde
# fʌˈsvenˀə
# ------------------------------------------------------
# gå bort
# had space
# komme tilbage
# had space
# komme
# https://ordnet.dk/ddo/ordbog?query=komme
# ˈkʌmə
# ------------------------------------------------------
# gå ud
# had space
# gå ned
# had space
# klatre
# https://ordnet.dk/ddo/ordbog?query=klatre
# ˈkladʁʌ
# ------------------------------------------------------
# gå
# https://ordnet.dk/ddo/ordbog?query=ga%CC%8A
# no page, trying ODS
# no page at all
# fare
# https://ordnet.dk/ddo/ordbog?query=fare
# ˈfɑːɑ
# ------------------------------------------------------
# gå op
# had space
# løbe
# https://ordnet.dk/ddo/ordbog?query=l%C3%B8be
# ˈløːbə
# ------------------------------------------------------
# hinke
# https://ordnet.dk/ddo/ordbog?query=hinke
# ˈheŋgə
# ------------------------------------------------------
# halte
# https://ordnet.dk/ddo/ordbog?query=halte
# ˈhaldə
# ------------------------------------------------------
# gå
# https://ordnet.dk/ddo/ordbog?query=ga%CC%8A
# no page, trying ODS
# no page at all
# danse
# https://ordnet.dk/ddo/ordbog?query=danse
# ˈdansə
# ------------------------------------------------------
# sparke
# https://ordnet.dk/ddo/ordbog?query=sparke
# ˈsbɑːgə
# ------------------------------------------------------
# hoppe
# https://ordnet.dk/ddo/ordbog?query=hoppe
# ˈhʌbə
# ------------------------------------------------------
# springe
# https://ordnet.dk/ddo/ordbog?query=springe
# ˈsbʁεŋə
# ------------------------------------------------------
# glide
# https://ordnet.dk/ddo/ordbog?query=glide
# ˈgliːðə
# ------------------------------------------------------
# sidde på hug
# had space
# knæle
# https://ordnet.dk/ddo/ordbog?query=kn%C3%A6le
# ˈknεːlə
# ------------------------------------------------------
# krybe
# https://ordnet.dk/ddo/ordbog?query=krybe
# ˈkʁyːbə
# ------------------------------------------------------
# kravle
# https://ordnet.dk/ddo/ordbog?query=kravle
# ˈkʁɑwlə
# ------------------------------------------------------
# blæse
# https://ordnet.dk/ddo/ordbog?query=bl%C3%A6se
# ˈblεːsə
# ------------------------------------------------------
# flyve
# https://ordnet.dk/ddo/ordbog?query=flyve
# ˈflyːvə
# ------------------------------------------------------
# sejle
# https://ordnet.dk/ddo/ordbog?query=sejle
# ˈsɑjlə
# ------------------------------------------------------
# sprøjte
# https://ordnet.dk/ddo/ordbog?query=spr%C3%B8jte
# ˈsbʁʌjdə
# ------------------------------------------------------
# dykke
# https://ordnet.dk/ddo/ordbog?query=dykke
# ˈdøgə
# ------------------------------------------------------
# svømme
# https://ordnet.dk/ddo/ordbog?query=sv%C3%B8mme
# ˈsvœmə
# ------------------------------------------------------
# flyde
# https://ordnet.dk/ddo/ordbog?query=flyde
# ˈflyːðə
# ------------------------------------------------------
# synke
# https://ordnet.dk/ddo/ordbog?query=synke
# ˈsøŋgə
# ------------------------------------------------------
# sænke
# https://ordnet.dk/ddo/ordbog?query=s%C3%A6nke
# ˈsεŋgə
# ------------------------------------------------------
# flyde
# https://ordnet.dk/ddo/ordbog?query=flyde
# ˈflyːðə
# ------------------------------------------------------
# rinde
# https://ordnet.dk/ddo/ordbog?query=rinde
# ˈʁεnə
# ------------------------------------------------------
# ryste
# https://ordnet.dk/ddo/ordbog?query=ryste
# ˈʁœsdə
# ------------------------------------------------------
# gribe
# https://ordnet.dk/ddo/ordbog?query=gribe
# ˈgʁiːbə
# ------------------------------------------------------
# kaste
# https://ordnet.dk/ddo/ordbog?query=kaste
# ˈkasdə
# ------------------------------------------------------
# dryppe
# https://ordnet.dk/ddo/ordbog?query=dryppe
# ˈdʁœbə
# ------------------------------------------------------
# falde
# https://ordnet.dk/ddo/ordbog?query=falde
# ˈfalə
# ------------------------------------------------------
# løfte
# https://ordnet.dk/ddo/ordbog?query=l%C3%B8fte
# ˈløfdə
# ------------------------------------------------------
# hæve
# https://ordnet.dk/ddo/ordbog?query=h%C3%A6ve
# ˈhεːvə
# ------------------------------------------------------
# stå op
# had space
# dreje
# https://ordnet.dk/ddo/ordbog?query=dreje
# ˈdʁɑjə
# ------------------------------------------------------
# tabe
# https://ordnet.dk/ddo/ordbog?query=tabe
# ˈtæːbə
# ------------------------------------------------------
# rulle
# https://ordnet.dk/ddo/ordbog?query=rulle
# ˈʁulə
# ------------------------------------------------------
# vinde
# https://ordnet.dk/ddo/ordbog?query=vinde
# ˈvenə
# ------------------------------------------------------
# svøbe
# https://ordnet.dk/ddo/ordbog?query=sv%C3%B8be
# ˈsvøːbə
# ------------------------------------------------------
# vikle
# https://ordnet.dk/ddo/ordbog?query=vikle
# ˈveglə
# ------------------------------------------------------
# dreje
# https://ordnet.dk/ddo/ordbog?query=dreje
# ˈdʁɑjə
# ------------------------------------------------------
# sno
# https://ordnet.dk/ddo/ordbog?query=sno
# ˈsnoˀ
# ------------------------------------------------------
# vende
# https://ordnet.dk/ddo/ordbog?query=vende
# ˈvεnə
# ------------------------------------------------------
# bevæge
# https://ordnet.dk/ddo/ordbog?query=bev%C3%A6ge
# beˈvεˀjə
# ------------------------------------------------------
# røre
# https://ordnet.dk/ddo/ordbog?query=r%C3%B8re
# ˈʁɶːʌ
# ------------------------------------------------------
# male
# https://ordnet.dk/ddo/ordbog?query=male
# ˈmæːlə
# ------------------------------------------------------
# mejsel
# https://ordnet.dk/ddo/ordbog?query=mejsel
# ˈmɑjˀsəl
# ------------------------------------------------------
# maling
# https://ordnet.dk/ddo/ordbog?query=maling
# ˈmæːleŋ
# ------------------------------------------------------
# farve
# https://ordnet.dk/ddo/ordbog?query=farve
# ˈfɑːvə
# ------------------------------------------------------
# statue
# https://ordnet.dk/ddo/ordbog?query=statue
# ˈsdæˀtuə
# ------------------------------------------------------
# billedhugger
# https://ordnet.dk/ddo/ordbog?query=billedhugger
# ˈbeləðˌhɔgʌ
# ------------------------------------------------------
# udhugge
# https://ordnet.dk/ddo/ordbog?query=udhugge
# nan
# ------------------------------------------------------
# vifte
# https://ordnet.dk/ddo/ordbog?query=vifte
# ˈvefdə
# ------------------------------------------------------
# vifte
# https://ordnet.dk/ddo/ordbog?query=vifte
# ˈvefdə
# ------------------------------------------------------
# dække
# https://ordnet.dk/ddo/ordbog?query=d%C3%A6kke
# ˈdεgə
# ------------------------------------------------------
# måtte
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Atte
# no page, trying ODS
# no page at all
# kurv
# https://ordnet.dk/ddo/ordbog?query=kurv
# ˈkuɐ̯ˀw
# ------------------------------------------------------
# flette
# https://ordnet.dk/ddo/ordbog?query=flette
# ˈflεdə
# ------------------------------------------------------
# glas
# https://ordnet.dk/ddo/ordbog?query=glas
# ˈglas
# ------------------------------------------------------
# ler
# https://ordnet.dk/ddo/ordbog?query=ler
# ˈleˀɐ̯
# ------------------------------------------------------
# forme
# https://ordnet.dk/ddo/ordbog?query=forme
# ˈfɒːmə
# ------------------------------------------------------
# danne
# https://ordnet.dk/ddo/ordbog?query=danne
# ˈdanə
# ------------------------------------------------------
# pottemager
# https://ordnet.dk/ddo/ordbog?query=pottemager
# ˈpʌdəˌmæˀjʌ
# ------------------------------------------------------
# tin
# https://ordnet.dk/ddo/ordbog?query=tin
# ˈten
# ------------------------------------------------------
# blik
# https://ordnet.dk/ddo/ordbog?query=blik
# ˈbleg
# ------------------------------------------------------
# bly
# https://ordnet.dk/ddo/ordbog?query=bly
# ˈblyˀ
# ------------------------------------------------------
# jern
# https://ordnet.dk/ddo/ordbog?query=jern
# ˈjæɐ̯ˀn
# ------------------------------------------------------
# kobber
# https://ordnet.dk/ddo/ordbog?query=kobber
# ˈkɒwˀʌ
# ------------------------------------------------------
# bronze
# https://ordnet.dk/ddo/ordbog?query=bronze
# ˈbʁʌŋsə
# ------------------------------------------------------
# sølv
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8lv
# ˈsøl
# ------------------------------------------------------
# guld
# https://ordnet.dk/ddo/ordbog?query=guld
# ˈgul
# ------------------------------------------------------
# støbe
# https://ordnet.dk/ddo/ordbog?query=st%C3%B8be
# ˈsdøːbə
# ------------------------------------------------------
# ambolt
# https://ordnet.dk/ddo/ordbog?query=ambolt
# ˈɑmˌbʌlˀd
# ------------------------------------------------------
# smede
# https://ordnet.dk/ddo/ordbog?query=smede
# ˈsmeːðə
# ------------------------------------------------------
# smed
# https://ordnet.dk/ddo/ordbog?query=smed
# ˈsmeð
# ------------------------------------------------------
# lim
# https://ordnet.dk/ddo/ordbog?query=lim
# ˈliˀm
# ------------------------------------------------------
# søm
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8m
# ˈsœmˀ
# ------------------------------------------------------
# hammer
# https://ordnet.dk/ddo/ordbog?query=hammer
# ˈhɑmʌ
# ------------------------------------------------------
# sav
# https://ordnet.dk/ddo/ordbog?query=sav
# ˈsæˀv
# ------------------------------------------------------
# udhule
# https://ordnet.dk/ddo/ordbog?query=udhule
# -ˌhuˀlə
# ------------------------------------------------------
# bore
# https://ordnet.dk/ddo/ordbog?query=bore
# ˈboːʌ
# ------------------------------------------------------
# bygge
# https://ordnet.dk/ddo/ordbog?query=bygge
# ˈbygə
# ------------------------------------------------------
# tømrer
# https://ordnet.dk/ddo/ordbog?query=t%C3%B8mrer
# ˈtœmʁʌ
# ------------------------------------------------------
# værktøj
# https://ordnet.dk/ddo/ordbog?query=v%C3%A6rkt%C3%B8j
# ˈvæɐ̯gˌtʌj
# ------------------------------------------------------
# redskab
# https://ordnet.dk/ddo/ordbog?query=redskab
# ˈʁεðˌsgæˀb
# ------------------------------------------------------
# kost
# https://ordnet.dk/ddo/ordbog?query=kost
# ˈkɔsd
# ------------------------------------------------------
# vaske
# https://ordnet.dk/ddo/ordbog?query=vaske
# ˈvasgə
# ------------------------------------------------------
# tvætte
# https://ordnet.dk/ddo/ordbog?query=tv%C3%A6tte
# ˈtvεdə
# ------------------------------------------------------
# feje
# https://ordnet.dk/ddo/ordbog?query=feje
# ˈfɑjə
# ------------------------------------------------------
# hælde
# https://ordnet.dk/ddo/ordbog?query=h%C3%A6lde
# ˈhεlə
# ------------------------------------------------------
# gyde
# https://ordnet.dk/ddo/ordbog?query=gyde
# ˈgyːðə
# ------------------------------------------------------
# skænke
# https://ordnet.dk/ddo/ordbog?query=sk%C3%A6nke
# ˈsgεŋgə
# ------------------------------------------------------
# presse
# https://ordnet.dk/ddo/ordbog?query=presse
# ˈpʁasə
# ------------------------------------------------------
# vride
# https://ordnet.dk/ddo/ordbog?query=vride
# ˈvʁiːðə
# ------------------------------------------------------
# trykke
# https://ordnet.dk/ddo/ordbog?query=trykke
# ˈtʁœgə
# ------------------------------------------------------
# presse
# https://ordnet.dk/ddo/ordbog?query=presse
# ˈpʁasə
# ------------------------------------------------------
# hænge op
# had space
# brede ud
# had space
# strø
# https://ordnet.dk/ddo/ordbog?query=str%C3%B8
# ˈsdʁœˀ
# ------------------------------------------------------
# trække
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6kke
# ˈtʁagə
# ------------------------------------------------------
# drage
# https://ordnet.dk/ddo/ordbog?query=drage
# ˈdʁɑːwə
# ------------------------------------------------------
# strække
# https://ordnet.dk/ddo/ordbog?query=str%C3%A6kke
# ˈsdʁagə
# ------------------------------------------------------
# spænde
# https://ordnet.dk/ddo/ordbog?query=sp%C3%A6nde
# ˈsbεnə
# ------------------------------------------------------
# gnide
# https://ordnet.dk/ddo/ordbog?query=gnide
# ˈgniːðə
# ------------------------------------------------------
# flå
# https://ordnet.dk/ddo/ordbog?query=fla%CC%8A
# no page, trying ODS
# no page at all
# rive
# https://ordnet.dk/ddo/ordbog?query=rive
# ˈʁiːvə
# ------------------------------------------------------
# spalte
# https://ordnet.dk/ddo/ordbog?query=spalte
# ˈsbaldə
# ------------------------------------------------------
# kløve
# https://ordnet.dk/ddo/ordbog?query=kl%C3%B8ve
# ˈkløːvə
# ------------------------------------------------------
# splitte
# https://ordnet.dk/ddo/ordbog?query=splitte
# ˈsbledə
# ------------------------------------------------------
# knækket
# https://ordnet.dk/ddo/ordbog?query=kn%C3%A6kket
# ˈknεg
# ------------------------------------------------------
# bryde
# https://ordnet.dk/ddo/ordbog?query=bryde
# ˈbʁyːðə
# ------------------------------------------------------
# brække
# https://ordnet.dk/ddo/ordbog?query=br%C3%A6kke
# ˈbʁagə
# ------------------------------------------------------
# økse
# https://ordnet.dk/ddo/ordbog?query=%C3%B8kse
# ˈøgsə
# ------------------------------------------------------
# økse
# https://ordnet.dk/ddo/ordbog?query=%C3%B8kse
# ˈøgsə
# ------------------------------------------------------
# saks
# https://ordnet.dk/ddo/ordbog?query=saks
# ˈsɑgs
# ------------------------------------------------------
# kniv
# https://ordnet.dk/ddo/ordbog?query=kniv
# ˈkniwˀ
# ------------------------------------------------------
# stikke
# https://ordnet.dk/ddo/ordbog?query=stikke
# ˈsdegə
# ------------------------------------------------------
# skære
# https://ordnet.dk/ddo/ordbog?query=sk%C3%A6re
# ˈsgεːʌ
# ------------------------------------------------------
# fælde
# https://ordnet.dk/ddo/ordbog?query=f%C3%A6lde
# ˈfεlə
# ------------------------------------------------------
# skære
# https://ordnet.dk/ddo/ordbog?query=sk%C3%A6re
# ˈsgεːʌ
# ------------------------------------------------------
# hugge
# https://ordnet.dk/ddo/ordbog?query=hugge
# ˈhɔgə
# ------------------------------------------------------
# slå med næve
# had space
# slå
# https://ordnet.dk/ddo/ordbog?query=sla%CC%8A
# no page, trying ODS
# no page at all
# knude
# https://ordnet.dk/ddo/ordbog?query=knude
# ˈknuːðə
# ------------------------------------------------------
# reb
# https://ordnet.dk/ddo/ordbog?query=reb
# ˈʁεˀb
# ------------------------------------------------------
# tov
# https://ordnet.dk/ddo/ordbog?query=tov
# ˈtɒw
# ------------------------------------------------------
# snor
# https://ordnet.dk/ddo/ordbog?query=snor
# ˈsnoˀɐ̯
# ------------------------------------------------------
# kæde
# https://ordnet.dk/ddo/ordbog?query=k%C3%A6de
# ˈkεːðə
# ------------------------------------------------------
# lænke
# https://ordnet.dk/ddo/ordbog?query=l%C3%A6nke
# ˈlεŋgə
# ------------------------------------------------------
# løse op
# had space
# binde
# https://ordnet.dk/ddo/ordbog?query=binde
# ˈbenə
# ------------------------------------------------------
# folde
# https://ordnet.dk/ddo/ordbog?query=folde
# ˈfʌlə
# ------------------------------------------------------
# bøje
# https://ordnet.dk/ddo/ordbog?query=b%C3%B8je
# ˈbʌjə
# ------------------------------------------------------
# arbejde
# https://ordnet.dk/ddo/ordbog?query=arbejde
# ˈɑːˌbɑjˀdə
# ------------------------------------------------------
# gøre
# https://ordnet.dk/ddo/ordbog?query=g%C3%B8re
# ˈgɶːʌ
# ------------------------------------------------------
# svamp
# https://ordnet.dk/ddo/ordbog?query=svamp
# ˈsvɑmˀb
# ------------------------------------------------------
# nælde
# https://ordnet.dk/ddo/ordbog?query=n%C3%A6lde
# ˈnεlə
# ------------------------------------------------------
# sukkerrør
# https://ordnet.dk/ddo/ordbog?query=sukkerr%C3%B8r
# nan
# ------------------------------------------------------
# bambus
# https://ordnet.dk/ddo/ordbog?query=bambus
# ˈbɑmbus
# ------------------------------------------------------
# græskar
# https://ordnet.dk/ddo/ordbog?query=gr%C3%A6skar
# ˈgʁaskɑ
# ------------------------------------------------------
# græskar
# https://ordnet.dk/ddo/ordbog?query=gr%C3%A6skar
# ˈgʁaskɑ
# ------------------------------------------------------
# sødkartoffel
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8dkartoffel
# ˈsøðˀ-
# ------------------------------------------------------
# banantræ
# https://ordnet.dk/ddo/ordbog?query=banantr%C3%A6
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# citron
# https://ordnet.dk/ddo/ordbog?query=citron
# siˈtʁoˀn
# ------------------------------------------------------
# kokosnød
# https://ordnet.dk/ddo/ordbog?query=kokosn%C3%B8d
# -ˌnøðˀ
# ------------------------------------------------------
# palme-træ
# https://ordnet.dk/ddo/ordbog?query=palme-tr%C3%A6
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# saft
# https://ordnet.dk/ddo/ordbog?query=saft
# ˈsɑfd
# ------------------------------------------------------
# bark
# https://ordnet.dk/ddo/ordbog?query=bark
# ˈbɑːg
# ------------------------------------------------------
# gaffelgren
# https://ordnet.dk/ddo/ordbog?query=gaffelgren
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# træstamme
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6stamme
# nan
# ------------------------------------------------------
# træstup
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6stup
# no page, trying ODS
# no page at all
# pibe
# https://ordnet.dk/ddo/ordbog?query=pibe
# ˈpiːbə
# ------------------------------------------------------
# ryge
# https://ordnet.dk/ddo/ordbog?query=ryge
# ˈʁyːə
# ------------------------------------------------------
# tobak
# https://ordnet.dk/ddo/ordbog?query=tobak
# toˈbɑg
# ------------------------------------------------------
# vin-ranke
# https://ordnet.dk/ddo/ordbog?query=vin-ranke
# nan
# ------------------------------------------------------
# vin-stok
# https://ordnet.dk/ddo/ordbog?query=vin-stok
# nan
# ------------------------------------------------------
# agern
# https://ordnet.dk/ddo/ordbog?query=agern
# ˈæˀjʌn
# ------------------------------------------------------
# gran
# https://ordnet.dk/ddo/ordbog?query=gran
# ˈgʁɑn
# ------------------------------------------------------
# fyr
# https://ordnet.dk/ddo/ordbog?query=fyr
# ˈfyɐ̯ˀ
# ------------------------------------------------------
# birk
# https://ordnet.dk/ddo/ordbog?query=birk
# ˈbiɐ̯g
# ------------------------------------------------------
# bøg
# https://ordnet.dk/ddo/ordbog?query=b%C3%B8g
# ˈbøˀj
# ------------------------------------------------------
# eg
# https://ordnet.dk/ddo/ordbog?query=eg
# ˈeˀj
# ------------------------------------------------------
# træ
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6
# ˈtʁεˀ
# ------------------------------------------------------
# blomst
# https://ordnet.dk/ddo/ordbog?query=blomst
# ˈblʌmˀsd
# ------------------------------------------------------
# blad
# https://ordnet.dk/ddo/ordbog?query=blad
# ˈblað
# ------------------------------------------------------
# løv
# https://ordnet.dk/ddo/ordbog?query=l%C3%B8v
# ˈløˀw
# ------------------------------------------------------
# gren
# https://ordnet.dk/ddo/ordbog?query=gren
# ˈgʁεˀn
# ------------------------------------------------------
# rod
# https://ordnet.dk/ddo/ordbog?query=rod
# ˈʁoˀð
# ------------------------------------------------------
# plante
# https://ordnet.dk/ddo/ordbog?query=plante
# ˈplandə
# ------------------------------------------------------
# hø
# https://ordnet.dk/ddo/ordbog?query=h%C3%B8
# ˈhœ
# ------------------------------------------------------
# plante
# https://ordnet.dk/ddo/ordbog?query=plante
# ˈplandə
# ------------------------------------------------------
# urt
# https://ordnet.dk/ddo/ordbog?query=urt
# ˈuɐ̯ˀd
# ------------------------------------------------------
# græs
# https://ordnet.dk/ddo/ordbog?query=gr%C3%A6s
# ˈgʁas
# ------------------------------------------------------
# ris
# https://ordnet.dk/ddo/ordbog?query=ris
# ˈʁiˀs
# ------------------------------------------------------
# majs
# https://ordnet.dk/ddo/ordbog?query=majs
# ˈmɑjˀs
# ------------------------------------------------------
# havre
# https://ordnet.dk/ddo/ordbog?query=havre
# ˈhɑwʁʌ
# ------------------------------------------------------
# rug
# https://ordnet.dk/ddo/ordbog?query=rug
# ˈʁuˀ
# ------------------------------------------------------
# hvede
# https://ordnet.dk/ddo/ordbog?query=hvede
# ˈveːðə
# ------------------------------------------------------
# byg
# https://ordnet.dk/ddo/ordbog?query=byg
# ˈbyg
# ------------------------------------------------------
# korn
# https://ordnet.dk/ddo/ordbog?query=korn
# ˈkoɐ̯ˀn
# ------------------------------------------------------
# høst
# https://ordnet.dk/ddo/ordbog?query=h%C3%B8st
# ˈhøsd
# ------------------------------------------------------
# grøde
# https://ordnet.dk/ddo/ordbog?query=gr%C3%B8de
# ˈgʁœːðə
# ------------------------------------------------------
# lo
# https://ordnet.dk/ddo/ordbog?query=lo
# ˈloˀ
# ------------------------------------------------------
# tærske
# ...
# by
# https://ordnet.dk/ddo/ordbog?query=by
# ˈbyˀ
# ------------------------------------------------------
# stad
# https://ordnet.dk/ddo/ordbog?query=stad
# ˈsdað
# ------------------------------------------------------
# landsby
# https://ordnet.dk/ddo/ordbog?query=landsby
# ˈlanˀsˌbyˀ
# ------------------------------------------------------
# grænse
# https://ordnet.dk/ddo/ordbog?query=gr%C3%A6nse
# ˈgʁansə
# ------------------------------------------------------
# folk
# https://ordnet.dk/ddo/ordbog?query=folk
# ˈfʌlˀg
# ------------------------------------------------------
# stamme
# https://ordnet.dk/ddo/ordbog?query=stamme
# ˈsdɑmə
# ------------------------------------------------------
# slægt
# https://ordnet.dk/ddo/ordbog?query=sl%C3%A6gt
# ˈslεgd
# ------------------------------------------------------
# høvding
# https://ordnet.dk/ddo/ordbog?query=h%C3%B8vding
# ˈhœwdeŋ
# ------------------------------------------------------
# stok
# https://ordnet.dk/ddo/ordbog?query=stok
# ˈsdʌg
# ------------------------------------------------------
# styre
# https://ordnet.dk/ddo/ordbog?query=styre
# ˈsdyːʌ
# ------------------------------------------------------
# herske
# https://ordnet.dk/ddo/ordbog?query=herske
# ˈhæɐ̯sgə
# ------------------------------------------------------
# konge
# https://ordnet.dk/ddo/ordbog?query=konge
# ˈkʌŋə
# ------------------------------------------------------
# dronning
# https://ordnet.dk/ddo/ordbog?query=dronning
# ˈdʁʌneŋ
# ------------------------------------------------------
# adelig
# https://ordnet.dk/ddo/ordbog?query=adelig
# ˈæˀðəli
# ------------------------------------------------------
# adelsmand
# https://ordnet.dk/ddo/ordbog?query=adelsmand
# nan
# ------------------------------------------------------
# borger
# https://ordnet.dk/ddo/ordbog?query=borger
# ˈbɒːwʌ
# ------------------------------------------------------
# herre
# https://ordnet.dk/ddo/ordbog?query=herre
# ˈhæɐ̯ʌ
# ------------------------------------------------------
# slave
# https://ordnet.dk/ddo/ordbog?query=slave
# ˈslæːvə
# ------------------------------------------------------
# tjener
# https://ordnet.dk/ddo/ordbog?query=tjener
# ˈtjεːnʌ
# ------------------------------------------------------
# fri
# https://ordnet.dk/ddo/ordbog?query=fri
# ˈfʁiˀ
# ------------------------------------------------------
# befale
# https://ordnet.dk/ddo/ordbog?query=befale
# beˈfæˀlə
# ------------------------------------------------------
# byde
# https://ordnet.dk/ddo/ordbog?query=byde
# ˈbyːðə
# ------------------------------------------------------
# lyde
# https://ordnet.dk/ddo/ordbog?query=lyde
# ˈlyːðə
# ------------------------------------------------------
# tillade
# https://ordnet.dk/ddo/ordbog?query=tillade
# ˈteˌlæˀðə
# ------------------------------------------------------
# ven
# https://ordnet.dk/ddo/ordbog?query=ven
# ˈvεn
# ------------------------------------------------------
# fjende
# https://ordnet.dk/ddo/ordbog?query=fjende
# ˈfjenə
# ------------------------------------------------------
# uven
# https://ordnet.dk/ddo/ordbog?query=uven
# ˈuˌvεn
# ------------------------------------------------------
# nabo
# https://ordnet.dk/ddo/ordbog?query=nabo
# ˈnæːbo
# ------------------------------------------------------
# fremmed
# https://ordnet.dk/ddo/ordbog?query=fremmed
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# gæst
# https://ordnet.dk/ddo/ordbog?query=g%C3%A6st
# ˈgεsd
# ------------------------------------------------------
# vært
# https://ordnet.dk/ddo/ordbog?query=v%C3%A6rt
# ˈvæɐ̯d
# ------------------------------------------------------
# hjælpe
# https://ordnet.dk/ddo/ordbog?query=hj%C3%A6lpe
# ˈjεlbə
# ------------------------------------------------------
# hindre
# https://ordnet.dk/ddo/ordbog?query=hindre
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# for-hindre
# https://ordnet.dk/ddo/ordbog?query=for-hindre
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# skik
# https://ordnet.dk/ddo/ordbog?query=skik
# ˈsgig
# ------------------------------------------------------
# vane
# https://ordnet.dk/ddo/ordbog?query=vane
# ˈvæːnə
# ------------------------------------------------------
# strid
# https://ordnet.dk/ddo/ordbog?query=strid
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# tvist
# https://ordnet.dk/ddo/ordbog?query=tvist
# ˈtvesd
# ------------------------------------------------------
# sammensværgelse
# https://ordnet.dk/ddo/ordbog?query=sammensv%C3%A6rgelse
# -ˌsvæɐ̯ˀwəlsə
# ------------------------------------------------------
# møde
# https://ordnet.dk/ddo/ordbog?query=m%C3%B8de
# ˈmøːðə
# ------------------------------------------------------
# prostitueret
# https://ordnet.dk/ddo/ordbog?query=prostitueret
# pʁosdituˈeˀʌð
# ------------------------------------------------------
# slås
# https://ordnet.dk/ddo/ordbog?query=sla%CC%8As
# no page, trying ODS
# no page at all
# kæmpe
# https://ordnet.dk/ddo/ordbog?query=k%C3%A6mpe
# ˈkεmbə
# ------------------------------------------------------
# krig
# https://ordnet.dk/ddo/ordbog?query=krig
# ˈkʁiˀ
# ------------------------------------------------------
# slag
# https://ordnet.dk/ddo/ordbog?query=slag
# ˈslæˀj
# ------------------------------------------------------
# fred
# https://ordnet.dk/ddo/ordbog?query=fred
# ˈfʁεð
# ------------------------------------------------------
# hær
# https://ordnet.dk/ddo/ordbog?query=h%C3%A6r
# ˈhεˀɐ̯
# ------------------------------------------------------
# armé
# https://ordnet.dk/ddo/ordbog?query=arme%CC%81
# no page, trying ODS
# no page at all
# soldat
# https://ordnet.dk/ddo/ordbog?query=soldat
# solˈdæˀd
# ------------------------------------------------------
# våben
# https://ordnet.dk/ddo/ordbog?query=va%CC%8Aben
# no page, trying ODS
# no page at all
# kølle
# https://ordnet.dk/ddo/ordbog?query=k%C3%B8lle
# ˈkølə
# ------------------------------------------------------
# stridsøkse
# https://ordnet.dk/ddo/ordbog?query=strids%C3%B8kse
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# slynge
# https://ordnet.dk/ddo/ordbog?query=slynge
# ˈsløŋə
# ------------------------------------------------------
# bue
# https://ordnet.dk/ddo/ordbog?query=bue
# ˈbuːə
# ------------------------------------------------------
# pil
# https://ordnet.dk/ddo/ordbog?query=pil
# ˈpiˀl
# ------------------------------------------------------
# spyd
# https://ordnet.dk/ddo/ordbog?query=spyd
# ˈsbyð
# ------------------------------------------------------
# lanse
# https://ordnet.dk/ddo/ordbog?query=lanse
# ˈlansə
# ------------------------------------------------------
# sværd
# https://ordnet.dk/ddo/ordbog?query=sv%C3%A6rd
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# gevær
# https://ordnet.dk/ddo/ordbog?query=gev%C3%A6r
# geˈvεˀɐ̯
# ------------------------------------------------------
# bøsse
# https://ordnet.dk/ddo/ordbog?query=b%C3%B8sse
# ˈbøsə
# ------------------------------------------------------
# kanon
# https://ordnet.dk/ddo/ordbog?query=kanon
# kaˈnoˀn
# ------------------------------------------------------
# rustning
# https://ordnet.dk/ddo/ordbog?query=rustning
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# harnisk
# https://ordnet.dk/ddo/ordbog?query=harnisk
# ˈhɑːnisg
# ------------------------------------------------------
# hjelm
# https://ordnet.dk/ddo/ordbog?query=hjelm
# ˈjεlˀm
# ------------------------------------------------------
# skjold
# https://ordnet.dk/ddo/ordbog?query=skjold
# ˈsgjʌlˀ
# ------------------------------------------------------
# fæstning
# https://ordnet.dk/ddo/ordbog?query=f%C3%A6stning
# ˈfεsdneŋ
# ------------------------------------------------------
# tårn
# https://ordnet.dk/ddo/ordbog?query=ta%CC%8Arn
# no page, trying ODS
# no page at all
# sejr
# https://ordnet.dk/ddo/ordbog?query=sejr
# ˈsɑjˀʌ
# ------------------------------------------------------
# nederlag
# https://ordnet.dk/ddo/ordbog?query=nederlag
# ˈneðʌˌlæjˀ
# ------------------------------------------------------
# angreb
# https://ordnet.dk/ddo/ordbog?query=angreb
# ˈanˌgʁεˀb
# ------------------------------------------------------
# forsvar
# https://ordnet.dk/ddo/ordbog?query=forsvar
# ˈfɒːˌsvɑˀ
# ------------------------------------------------------
# retræte
# https://ordnet.dk/ddo/ordbog?query=retr%C3%A6te
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# overgive
# https://ordnet.dk/ddo/ordbog?query=overgive
# -ˌgiˀ
# ------------------------------------------------------
# fange
# https://ordnet.dk/ddo/ordbog?query=fange
# ˈfɑŋə
# ------------------------------------------------------
# vagt
# https://ordnet.dk/ddo/ordbog?query=vagt
# ˈvɑgd
# ------------------------------------------------------
# bytte
# https://ordnet.dk/ddo/ordbog?query=bytte
# ˈbydə
# ------------------------------------------------------
# rov
# https://ordnet.dk/ddo/ordbog?query=rov
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# baghold
# https://ordnet.dk/ddo/ordbog?query=baghold
# ˈbɑwˌhʌlˀ
# ------------------------------------------------------
# fisker
# https://ordnet.dk/ddo/ordbog?query=fisker
# ˈfesgʌ
# ------------------------------------------------------
# fiskekrog
# https://ordnet.dk/ddo/ordbog?query=fiskekrog
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# snøre
# https://ordnet.dk/ddo/ordbog?query=sn%C3%B8re
# ˈsnɶːʌ
# ------------------------------------------------------
# fiskenet
# https://ordnet.dk/ddo/ordbog?query=fiskenet
# nan
# ------------------------------------------------------
# lokkemad
# https://ordnet.dk/ddo/ordbog?query=lokkemad
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# jage
# https://ordnet.dk/ddo/ordbog?query=jage
# ˈjæːjə
# ------------------------------------------------------
# skyde
# https://ordnet.dk/ddo/ordbog?query=skyde
# ˈsgyːðə
# ------------------------------------------------------
# ramme forbi
# had space
# fælde
# https://ordnet.dk/ddo/ordbog?query=f%C3%A6lde
# ˈfεlə
# ------------------------------------------------------
# lov
# https://ordnet.dk/ddo/ordbog?query=lov
# ˈlɒw
# ------------------------------------------------------
# ret
# https://ordnet.dk/ddo/ordbog?query=ret
# ˈʁad
# ------------------------------------------------------
# dømme
# https://ordnet.dk/ddo/ordbog?query=d%C3%B8mme
# ˈdœmə
# ------------------------------------------------------
# dom
# https://ordnet.dk/ddo/ordbog?query=dom
# ˈdʌmˀ
# ------------------------------------------------------
# dommer
# https://ordnet.dk/ddo/ordbog?query=dommer
# ˈdʌmʌ
# ------------------------------------------------------
# sagsøger
# https://ordnet.dk/ddo/ordbog?query=sags%C3%B8ger
# ˈsɑwˌsøˀjʌ
# ------------------------------------------------------
# klager
# https://ordnet.dk/ddo/ordbog?query=klager
# ˈklæːjʌ
# ------------------------------------------------------
# tiltalte
# https://ordnet.dk/ddo/ordbog?query=tiltalte
# ˈtelˌtæˀlə
# ------------------------------------------------------
# vidne
# https://ordnet.dk/ddo/ordbog?query=vidne
# ˈviðnə
# ------------------------------------------------------
# sværge
# https://ordnet.dk/ddo/ordbog?query=sv%C3%A6rge
# ˈsvæɐ̯wə
# ------------------------------------------------------
# ed
# https://ordnet.dk/ddo/ordbog?query=ed
# ˈeˀˈdeˀ
# ------------------------------------------------------
# anklage
# https://ordnet.dk/ddo/ordbog?query=anklage
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# beskylde
# https://ordnet.dk/ddo/ordbog?query=beskylde
# beˈsgylˀə
# ------------------------------------------------------
# dømme
# https://ordnet.dk/ddo/ordbog?query=d%C3%B8mme
# ˈdœmə
# ------------------------------------------------------
# overbevise
# https://ordnet.dk/ddo/ordbog?query=overbevise
# ˈɒwʌbeˌviˀsə
# ------------------------------------------------------
# frikende
# https://ordnet.dk/ddo/ordbog?query=frikende
# -ˌkεnˀə
# ------------------------------------------------------
# frifinde
# https://ordnet.dk/ddo/ordbog?query=frifinde
# -ˌfenˀə
# ------------------------------------------------------
# skyldig
# https://ordnet.dk/ddo/ordbog?query=skyldig
# ˈsgyldi
# ------------------------------------------------------
# uskyldig
# https://ordnet.dk/ddo/ordbog?query=uskyldig
# uˈsgylˀdi
# ------------------------------------------------------
# straf
# https://ordnet.dk/ddo/ordbog?query=straf
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# bøde
# https://ordnet.dk/ddo/ordbog?query=b%C3%B8de
# ˈbøːðə
# ------------------------------------------------------
# fængsel
# https://ordnet.dk/ddo/ordbog?query=f%C3%A6ngsel
# ˈfεŋˀsəl
# ------------------------------------------------------
# mord
# https://ordnet.dk/ddo/ordbog?query=mord
# ˈmoˀɐ̯
# ------------------------------------------------------
# ægteskabsbrud
# https://ordnet.dk/ddo/ordbog?query=%C3%A6gteskabsbrud
# ˈεgdəsgabsˌbʁuð
# ------------------------------------------------------
# voldtægt
# https://ordnet.dk/ddo/ordbog?query=voldt%C3%A6gt
# ˈvʌlˌtεgd
# ------------------------------------------------------
# mordbrand
# https://ordnet.dk/ddo/ordbog?query=mordbrand
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# mened
# https://ordnet.dk/ddo/ordbog?query=mened
# ˈmeːˌneðˀ
# ------------------------------------------------------
# stjæle
# https://ordnet.dk/ddo/ordbog?query=stj%C3%A6le
# ˈsdjεːlə
# ------------------------------------------------------
# tyv
# https://ordnet.dk/ddo/ordbog?query=tyv
# ˈtywˀ
# ------------------------------------------------------
# religion
# https://ordnet.dk/ddo/ordbog?query=religion
# ʁεliˈgjoˀn
# ------------------------------------------------------
# Gud
# https://ordnet.dk/ddo/ordbog?query=Gud
# no page, trying ODS
# nan(ods)
# ------------------------------------------------------
# tempel
# https://ordnet.dk/ddo/ordbog?query=tempel
# ˈtεmˀbəl
# ------------------------------------------------------
# alter
# https://ordnet.dk/ddo/ordbog?query=alter
# ˈaldʌ
# ------------------------------------------------------
# offer
# https://ordnet.dk/ddo/ordbog?query=offer
# ˈʌfʌ
# ------------------------------------------------------
# tilbede
# https://ordnet.dk/ddo/ordbog?query=tilbede
# -ˌbeˀðə
# ------------------------------------------------------
# bede
# https://ordnet.dk/ddo/ordbog?query=bede
# ˈbeːðə
# ------------------------------------------------------
# præst
# https://ordnet.dk/ddo/ordbog?query=pr%C3%A6st
# ˈpʁasd
# ------------------------------------------------------
# hellig
# https://ordnet.dk/ddo/ordbog?query=hellig
# ˈhεli
# ------------------------------------------------------
# prædike
# https://ordnet.dk/ddo/ordbog?query=pr%C3%A6dike
# ˈpʁεðəgə
# ------------------------------------------------------
# velsigne
# https://ordnet.dk/ddo/ordbog?query=velsigne
# vεlˈsiˀnə
# ------------------------------------------------------
# forbande
# https://ordnet.dk/ddo/ordbog?query=forbande
# fʌˈbanˀə
# ------------------------------------------------------
# faste
# https://ordnet.dk/ddo/ordbog?query=faste
# ˈfæːsdə
# ------------------------------------------------------
# himmel
# https://ordnet.dk/ddo/ordbog?query=himmel
# ˈheməl
# ------------------------------------------------------
# helvede
# https://ordnet.dk/ddo/ordbog?query=helvede
# ˈhεlvəðə
# ------------------------------------------------------
# ond ånd
# had space
# afgud
# https://ordnet.dk/ddo/ordbog?query=afgud
# ˈɑwˌguð
# ------------------------------------------------------
# trolddom
# https://ordnet.dk/ddo/ordbog?query=trolddom
# ˈtʁʌlˌdʌmˀ
# ------------------------------------------------------
# magi
# https://ordnet.dk/ddo/ordbog?query=magi
# maˈgiˀ
# ------------------------------------------------------
# heks
# https://ordnet.dk/ddo/ordbog?query=heks
# ˈhεgs
# ------------------------------------------------------
# troldkvinde
# https://ordnet.dk/ddo/ordbog?query=troldkvinde
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# fe
# https://ordnet.dk/ddo/ordbog?query=fe
# no page, trying ODS
# no pron in ODD, trying ODS
# no pron data either in ODD or ODS
# alf
# https://ordnet.dk/ddo/ordbog?query=alf
# ˈalˀf
# ------------------------------------------------------
# spøgelse
# https://ordnet.dk/ddo/ordbog?query=sp%C3%B8gelse
# ˈsbøːjəlsə
# ------------------------------------------------------
# omen
# https://ordnet.dk/ddo/ordbog?query=omen
# ˈoːmən
# ------------------------------------------------------
# varsel
# https://ordnet.dk/ddo/ordbog?query=varsel
# ˈvɑːsəl
# ------------------------------------------------------

# %%
danishWords['Phon'] = danishProns

# %%
danishWords.to_csv('danishOrthPhon.csv', encoding='utf-8')

# %% [markdown]
# # Second stage

# %%
wordsPostScrape = pd.read_csv('danishOrthPhon.csv')

# %%
notScraped = wordsPostScrape.loc[(pd.isnull(wordsPostScrape['Phon'])) | (wordsPostScrape['Phon'] == 'nan(ods)'), :]

# %%
firstScrape = [getPron(word) for word in list(notScraped['Orth'])] # because of an error in my code, this was actually a second scrape of DDO.
# Out:
# skynde sig
# had space
# tre gange
# had space
# to gange
# had space
# par
# https://ordnet.dk/ddo/ordbog?query=par
# no pron data
# få
# https://ordnet.dk/ddo/ordbog?query=fa%CC%8A
# no page at all
# al
# https://ordnet.dk/ddo/ordbog?query=al
# no pron data
# to
# https://ordnet.dk/ddo/ordbog?query=to
# no pron data
# små
# https://ordnet.dk/ddo/ordbog?query=sma%CC%8A
# no page at all
# måle
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Ale
# no page at all
# til-lukke
# https://ordnet.dk/ddo/ordbog?query=til-lukke
# nan
# ------------------------------------------------------
# åbne
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Abne
# no page at all
# lukke op
# had space
# hobe op
# had space
# samle op
# had space
# stå
# https://ordnet.dk/ddo/ordbog?query=sta%CC%8A
# no page at all
# ovenpå
# https://ordnet.dk/ddo/ordbog?query=ovenpa%CC%8A
# no page at all
# ved siden af
# had space
# dele med
# had space
# låne
# https://ordnet.dk/ddo/ordbog?query=la%CC%8Ane
# no page at all
# låne
# https://ordnet.dk/ddo/ordbog?query=la%CC%8Ane
# no page at all
# slippe løs
# had space
# lede efter
# had space
# passe på
# had space
# give tilbage
# had space
# få
# https://ordnet.dk/ddo/ordbog?query=fa%CC%8A
# no page at all
# åre
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Are
# no page at all
# flåde
# https://ordnet.dk/ddo/ordbog?query=fla%CC%8Ade
# no page at all
# udlægger
# https://ordnet.dk/ddo/ordbog?query=udl%C3%A6gger
# nan
# ------------------------------------------------------
# båd
# https://ordnet.dk/ddo/ordbog?query=ba%CC%8Ad
# no page at all
# åg
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Ag
# no page at all
# bære under armen
# had space
# bære på hovedet
# had space
# bære på skulderen
# had space
# bære i hånden
# had space
# nærme sig
# had space
# nå
# https://ordnet.dk/ddo/ordbog?query=na%CC%8A
# no page at all
# gå bort
# had space
# komme tilbage
# had space
# gå ud
# had space
# gå ned
# had space
# gå
# https://ordnet.dk/ddo/ordbog?query=ga%CC%8A
# no page at all
# gå op
# had space
# gå
# https://ordnet.dk/ddo/ordbog?query=ga%CC%8A
# no page at all
# sidde på hug
# had space
# stå op
# had space
# udhugge
# https://ordnet.dk/ddo/ordbog?query=udhugge
# nan
# ------------------------------------------------------
# måtte
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Atte
# no page at all
# hænge op
# had space
# brede ud
# had space
# flå
# https://ordnet.dk/ddo/ordbog?query=fla%CC%8A
# no page at all
# slå med næve
# had space
# slå
# https://ordnet.dk/ddo/ordbog?query=sla%CC%8A
# no page at all
# løse op
# had space
# sukkerrør
# https://ordnet.dk/ddo/ordbog?query=sukkerr%C3%B8r
# nan
# ------------------------------------------------------
# banantræ
# https://ordnet.dk/ddo/ordbog?query=banantr%C3%A6
# no pron data
# palme-træ
# https://ordnet.dk/ddo/ordbog?query=palme-tr%C3%A6
# no pron data
# gaffelgren
# https://ordnet.dk/ddo/ordbog?query=gaffelgren
# no page at all
# træstamme
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6stamme
# nan
# ------------------------------------------------------
# træstup
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6stup
# no page at all
# vin-ranke
# https://ordnet.dk/ddo/ordbog?query=vin-ranke
# nan
# ------------------------------------------------------
# vin-stok
# https://ordnet.dk/ddo/ordbog?query=vin-stok
# nan
# ------------------------------------------------------
# slå
# https://ordnet.dk/ddo/ordbog?query=sla%CC%8A
# no page at all
# så
# https://ordnet.dk/ddo/ordbog?query=sa%CC%8A
# no page at all
# spade
# https://ordnet.dk/ddo/ordbog?query=spade
# ˈsbæːðə
# ------------------------------------------------------
# landmand
# https://ordnet.dk/ddo/ordbog?query=landmand
# nan
# ------------------------------------------------------
# lertegl
# https://ordnet.dk/ddo/ordbog?query=lertegl
# no page at all
# rygås
# https://ordnet.dk/ddo/ordbog?query=ryga%CC%8As
# no page at all
# stråtag
# https://ordnet.dk/ddo/ordbog?query=stra%CC%8Atag
# no page at all
# ildsted
# https://ordnet.dk/ddo/ordbog?query=ildsted
# nan
# ------------------------------------------------------
# dør-klinke
# https://ordnet.dk/ddo/ordbog?query=d%C3%B8r-klinke
# no page at all
# lås
# https://ordnet.dk/ddo/ordbog?query=la%CC%8As
# no page at all
# dør-stolpe
# https://ordnet.dk/ddo/ordbog?query=d%C3%B8r-stolpe
# nan
# ------------------------------------------------------
# forsamlingshus
# https://ordnet.dk/ddo/ordbog?query=forsamlingshus
# nan
# ------------------------------------------------------
# gård
# https://ordnet.dk/ddo/ordbog?query=ga%CC%8Ard
# no page at all
# havehus
# https://ordnet.dk/ddo/ordbog?query=havehus
# nan
# ------------------------------------------------------
# barberkniv
# https://ordnet.dk/ddo/ordbog?query=barberkniv
# nan
# ------------------------------------------------------
# håndklæde
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Andkl%C3%A6de
# no page at all
# hovedbeklædning
# https://ordnet.dk/ddo/ordbog?query=hovedbekl%C3%A6dning
# nan
# ------------------------------------------------------
# ørenring
# https://ordnet.dk/ddo/ordbog?query=%C3%B8renring
# no pron data
# halsbånd
# https://ordnet.dk/ddo/ordbog?query=halsba%CC%8And
# no page at all
# armbånd
# https://ordnet.dk/ddo/ordbog?query=armba%CC%8And
# no page at all
# nål
# https://ordnet.dk/ddo/ordbog?query=na%CC%8Al
# no page at all
# mantel
# https://ordnet.dk/ddo/ordbog?query=mantel
# no page at all
# tråd
# https://ordnet.dk/ddo/ordbog?query=tra%CC%8Ad
# no page at all
# nål
# https://ordnet.dk/ddo/ordbog?query=na%CC%8Al
# no page at all
# vævestol
# https://ordnet.dk/ddo/ordbog?query=v%C3%A6vestol
# nan
# ------------------------------------------------------
# tage på
# had space
# æggeblomme
# https://ordnet.dk/ddo/ordbog?query=%C3%A6ggeblomme
# nan
# ------------------------------------------------------
# rød pebber
# had space
# pebber
# https://ordnet.dk/ddo/ordbog?query=pebber
# no page at all
# elte
# https://ordnet.dk/ddo/ordbog?query=elte
# no page at all
# si
# https://ordnet.dk/ddo/ordbog?query=si
# no pron data
# aftensmad
# https://ordnet.dk/ddo/ordbog?query=aftensmad
# nan
# ------------------------------------------------------
# måltid
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Altid
# no page at all
# underkop
# https://ordnet.dk/ddo/ordbog?query=underkop
# nan
# ------------------------------------------------------
# skål
# https://ordnet.dk/ddo/ordbog?query=ska%CC%8Al
# no page at all
# lave mad
# had space
# rådden
# https://ordnet.dk/ddo/ordbog?query=ra%CC%8Adden
# no page at all
# rå
# https://ordnet.dk/ddo/ordbog?query=ra%CC%8A
# no page at all
# lægemiddel
# https://ordnet.dk/ddo/ordbog?query=l%C3%A6gemiddel
# nan
# ------------------------------------------------------
# år
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Ar
# no page at all
# sår
# https://ordnet.dk/ddo/ordbog?query=sa%CC%8Ar
# no page at all
# i live
# had space
# have samleje
# had space
# tisse
# https://ordnet.dk/ddo/ordbog?query=tisse
# ˈtisə
# ------------------------------------------------------
# vågne
# https://ordnet.dk/ddo/ordbog?query=va%CC%8Agne
# no page at all
# våge
# https://ordnet.dk/ddo/ordbog?query=va%CC%8Age
# no page at all
# brække sig
# had space
# hoste
# https://ordnet.dk/ddo/ordbog?query=hoste
# ˈhoːsdə
# ------------------------------------------------------
# hik
# https://ordnet.dk/ddo/ordbog?query=hik
# ˈheg
# ------------------------------------------------------
# gabe
# https://ordnet.dk/ddo/ordbog?query=gabe
# ˈgæːbə
# ------------------------------------------------------
# ånde
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Ande
# no page at all
# ånde
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Ande
# no page at all
# moderliv
# https://ordnet.dk/ddo/ordbog?query=moderliv
# no page at all
# bagdel
# https://ordnet.dk/ddo/ordbog?query=bagdel
# nan
# ------------------------------------------------------
# taille
# https://ordnet.dk/ddo/ordbog?query=taille
# no page at all
# involde
# https://ordnet.dk/ddo/ordbog?query=involde
# no page at all
# brystvorte
# https://ordnet.dk/ddo/ordbog?query=brystvorte
# nan
# ------------------------------------------------------
# tå
# https://ordnet.dk/ddo/ordbog?query=ta%CC%8A
# no page at all
# fodaftryk
# https://ordnet.dk/ddo/ordbog?query=fodaftryk
# nan
# ------------------------------------------------------
# lår
# https://ordnet.dk/ddo/ordbog?query=la%CC%8Ar
# no page at all
# fingernegl
# https://ordnet.dk/ddo/ordbog?query=fingernegl
# nan
# ------------------------------------------------------
# håndflade
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Andflade
# no page at all
# hånd
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8And
# no page at all
# håndled
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Andled
# no page at all
# armhule
# https://ordnet.dk/ddo/ordbog?query=armhule
# nan
# ------------------------------------------------------
# nøgleben
# https://ordnet.dk/ddo/ordbog?query=n%C3%B8gleben
# nan
# ------------------------------------------------------
# skulderblad
# https://ordnet.dk/ddo/ordbog?query=skulderblad
# nan
# ------------------------------------------------------
# ørevoks
# https://ordnet.dk/ddo/ordbog?query=%C3%B8revoks
# nan
# ------------------------------------------------------
# øjenhår
# https://ordnet.dk/ddo/ordbog?query=%C3%B8jenha%CC%8Ar
# no page at all
# øjelåg
# https://ordnet.dk/ddo/ordbog?query=%C3%B8jela%CC%8Ag
# no page at all
# øjenbryn
# https://ordnet.dk/ddo/ordbog?query=%C3%B8jenbryn
# nan
# ------------------------------------------------------
# hovedskal
# https://ordnet.dk/ddo/ordbog?query=hovedskal
# nan
# ------------------------------------------------------
# hjerneskal
# https://ordnet.dk/ddo/ordbog?query=hjerneskal
# nan
# ------------------------------------------------------
# åre
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Are
# no page at all
# skamhår
# https://ordnet.dk/ddo/ordbog?query=skamha%CC%8Ar
# no page at all
# hår
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Ar
# no page at all
# hår
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Ar
# no page at all
# lysbille
# https://ordnet.dk/ddo/ordbog?query=lysbille
# no page at all
# bikube
# https://ordnet.dk/ddo/ordbog?query=bikube
# nan
# ------------------------------------------------------
# bi
# https://ordnet.dk/ddo/ordbog?query=bi
# no pron data
# tusindben
# https://ordnet.dk/ddo/ordbog?query=tusindben
# no pron data
# ferskvandsål
# https://ordnet.dk/ddo/ordbog?query=ferskvandsa%CC%8Al
# no page at all
# fiskeskæl
# https://ordnet.dk/ddo/ordbog?query=fiskesk%C3%A6l
# nan
# ------------------------------------------------------
# papagøje
# https://ordnet.dk/ddo/ordbog?query=papag%C3%B8je
# no page at all
# måge
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Age
# no page at all
# gås
# https://ordnet.dk/ddo/ordbog?query=ga%CC%8As
# no page at all
# moderfår
# https://ordnet.dk/ddo/ordbog?query=moderfa%CC%8Ar
# no page at all
# får
# https://ordnet.dk/ddo/ordbog?query=fa%CC%8Ar
# no page at all
# kalv
# https://ordnet.dk/ddo/ordbog?query=kalv
# ˈkalˀv
# ------------------------------------------------------
# hun-
# https://ordnet.dk/ddo/ordbog?query=hun-
# no page at all
# han-
# https://ordnet.dk/ddo/ordbog?query=han-
# no page at all
# enkemand
# https://ordnet.dk/ddo/ordbog?query=enkemand
# nan
# ------------------------------------------------------
# forældreløs
# https://ordnet.dk/ddo/ordbog?query=for%C3%A6ldrel%C3%B8s
# nan
# ------------------------------------------------------
# søskendebarn
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8skendebarn
# nan
# ------------------------------------------------------
# sønnesøn
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8nnes%C3%B8n
# nan
# ------------------------------------------------------
# dattersøn
# https://ordnet.dk/ddo/ordbog?query=datters%C3%B8n
# nan
# ------------------------------------------------------
# sønnedatter
# https://ordnet.dk/ddo/ordbog?query=s%C3%B8nnedatter
# nan
# ------------------------------------------------------
# datterdatter
# https://ordnet.dk/ddo/ordbog?query=datterdatter
# nan
# ------------------------------------------------------
# gammel kvinde
# had space
# gammel mand
# had space
# tvillinge
# https://ordnet.dk/ddo/ordbog?query=tvillinge
# no page at all
# lillesøster
# https://ordnet.dk/ddo/ordbog?query=lilles%C3%B8ster
# nan
# ------------------------------------------------------
# gift kvinde
# had space
# gift mand
# had space
# giftermål
# https://ordnet.dk/ddo/ordbog?query=gifterma%CC%8Al
# no page at all
# gifte sig
# had space
# ægtemand
# https://ordnet.dk/ddo/ordbog?query=%C3%A6gtemand
# nan
# ------------------------------------------------------
# ung kvinde
# had space
# ung mand
# had space
# trækul
# https://ordnet.dk/ddo/ordbog?query=tr%C3%A6kul
# nan
# ------------------------------------------------------
# udryde
# https://ordnet.dk/ddo/ordbog?query=udryde
# no page at all
# tåge
# https://ordnet.dk/ddo/ordbog?query=ta%CC%8Age
# no page at all
# lynslag
# https://ordnet.dk/ddo/ordbog?query=lynslag
# no page at all
# tordenkile
# https://ordnet.dk/ddo/ordbog?query=tordenkile
# nan
# ------------------------------------------------------
# måne
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Ane
# no page at all
# jordskælv
# https://ordnet.dk/ddo/ordbog?query=jordsk%C3%A6lv
# nan
# ------------------------------------------------------
# vandfald
# https://ordnet.dk/ddo/ordbog?query=vandfald
# nan
# ------------------------------------------------------
# tidevande
# https://ordnet.dk/ddo/ordbog?query=tidevande
# no page at all
# indsø
# https://ordnet.dk/ddo/ordbog?query=inds%C3%B8
# nan
# ------------------------------------------------------
# daggry
# https://ordnet.dk/ddo/ordbog?query=daggry
# nan
# ------------------------------------------------------
# i dag
# had space
# i morgen
# had space
# i overmorgen
# had space
# i går
# had space
# i forgårs
# had space
# måned
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Aned
# no page at all
# år
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Ar
# no page at all
# forår
# https://ordnet.dk/ddo/ordbog?query=fora%CC%8Ar
# no page at all
# efterår
# https://ordnet.dk/ddo/ordbog?query=eftera%CC%8Ar
# no page at all
# årstid
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Arstid
# no page at all
# se på
# had space
# blå
# https://ordnet.dk/ddo/ordbog?query=bla%CC%8A
# no page at all
# røre ved
# had space
# hård
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Ard
# no page at all
# våd
# https://ordnet.dk/ddo/ordbog?query=va%CC%8Ad
# no page at all
# ånd
# https://ordnet.dk/ddo/ordbog?query=a%CC%8And
# no page at all
# tåre
# https://ordnet.dk/ddo/ordbog?query=ta%CC%8Are
# no page at all
# tapper
# https://ordnet.dk/ddo/ordbog?query=tapper
# ˈtɑbʌ
# ------------------------------------------------------
# håb
# https://ordnet.dk/ddo/ordbog?query=ha%CC%8Ab
# no page at all
# dårlig
# https://ordnet.dk/ddo/ordbog?query=da%CC%8Arlig
# no page at all
# grådig
# https://ordnet.dk/ddo/ordbog?query=gra%CC%8Adig
# no page at all
# ånd
# https://ordnet.dk/ddo/ordbog?query=a%CC%8And
# no page at all
# forstå
# https://ordnet.dk/ddo/ordbog?query=forsta%CC%8A
# no page at all
# tåbelig
# https://ordnet.dk/ddo/ordbog?query=ta%CC%8Abelig
# no page at all
# årsag
# https://ordnet.dk/ddo/ordbog?query=a%CC%8Arsag
# no page at all
# forråde
# https://ordnet.dk/ddo/ordbog?query=forra%CC%8Ade
# no page at all
# måde
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Ade
# no page at all
# hvordan?
# https://ordnet.dk/ddo/ordbog?query=hvordan%3F
# no page at all
# hvor mange?
# had space
# hvor meget?
# had space
# hvad?
# https://ordnet.dk/ddo/ordbog?query=hvad%3F
# no page at all
# hvornår?
# https://ordnet.dk/ddo/ordbog?query=hvorna%CC%8Ar%3F
# no page at all
# hvilken?
# https://ordnet.dk/ddo/ordbog?query=hvilken%3F
# no page at all
# hvem?
# https://ordnet.dk/ddo/ordbog?query=hvem%3F
# no page at all
# hvorfor?
# https://ordnet.dk/ddo/ordbog?query=hvorfor%3F
# no page at all
# råbe
# https://ordnet.dk/ddo/ordbog?query=ra%CC%8Abe
# no page at all
# tale (holde en)
# had space
# mål
# https://ordnet.dk/ddo/ordbog?query=ma%CC%8Al
# no page at all
# tilstå
# https://ordnet.dk/ddo/ordbog?query=tilsta%CC%8A
# no page at all
# afslå
# https://ordnet.dk/ddo/ordbog?query=afsla%CC%8A
# no page at all
# vægre sig ved
# had space
# rasle-
# https://ordnet.dk/ddo/ordbog?query=rasle-
# no page at all
# fosterland
# https://ordnet.dk/ddo/ordbog?query=fosterland
# no page at all
# adelsmand
# https://ordnet.dk/ddo/ordbog?query=adelsmand
# nan
# ------------------------------------------------------
# fremmed
# https://ordnet.dk/ddo/ordbog?query=fremmed
# ˈfʁaməð
# ------------------------------------------------------
# hindre
# https://ordnet.dk/ddo/ordbog?query=hindre
# ˈhendʁʌ
# ------------------------------------------------------
# for-hindre
# https://ordnet.dk/ddo/ordbog?query=for-hindre
# fʌˈhenˀdʁʌ
# ------------------------------------------------------
# strid
# https://ordnet.dk/ddo/ordbog?query=strid
# ˈsdʁiðˀ
# ------------------------------------------------------
# slås
# https://ordnet.dk/ddo/ordbog?query=sla%CC%8As
# no page at all
# armé
# https://ordnet.dk/ddo/ordbog?query=arme%CC%81
# no page at all
# våben
# https://ordnet.dk/ddo/ordbog?query=va%CC%8Aben
# no page at all
# stridsøkse
# https://ordnet.dk/ddo/ordbog?query=strids%C3%B8kse
# ˈsdʁiðs-
# ------------------------------------------------------
# sværd
# https://ordnet.dk/ddo/ordbog?query=sv%C3%A6rd
# ˈsvεˀɐ̯
# ------------------------------------------------------
# rustning
# https://ordnet.dk/ddo/ordbog?query=rustning
# ˈʁɔsdneŋ
# ------------------------------------------------------
# tårn
# https://ordnet.dk/ddo/ordbog?query=ta%CC%8Arn
# no page at all
# retræte
# https://ordnet.dk/ddo/ordbog?query=retr%C3%A6te
# ʁεˈtʁεːdə
# ------------------------------------------------------
# rov
# https://ordnet.dk/ddo/ordbog?query=rov
# ˈʁɒw
# ------------------------------------------------------
# fiskekrog
# https://ordnet.dk/ddo/ordbog?query=fiskekrog
# nan
# ------------------------------------------------------
# fiskenet
# https://ordnet.dk/ddo/ordbog?query=fiskenet
# nan
# ------------------------------------------------------
# lokkemad
# https://ordnet.dk/ddo/ordbog?query=lokkemad
# nan
# ------------------------------------------------------
# ramme forbi
# had space
# anklage
# https://ordnet.dk/ddo/ordbog?query=anklage
# ˈanˌklæːjə
# ------------------------------------------------------
# straf
# https://ordnet.dk/ddo/ordbog?query=straf
# ˈsdʁɑf
# ------------------------------------------------------
# mordbrand
# https://ordnet.dk/ddo/ordbog?query=mordbrand
# ˈmoɐ̯-
# ------------------------------------------------------
# Gud
# https://ordnet.dk/ddo/ordbog?query=Gud
# ˈguð
# ------------------------------------------------------
# ond ånd
# had space
# troldkvinde
# https://ordnet.dk/ddo/ordbog?query=troldkvinde
# ˈtʁʌl-
# ------------------------------------------------------
# fe
# https://ordnet.dk/ddo/ordbog?query=fe
# ˈfeˀ
# ------------------------------------------------------

# %%
import copy
firstScrape = copy.deepcopy(secondScrape)

# %%
notScraped['Phon'] = firstScrape
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def getPronODS(word):
    print(word)
    if ' ' in word:
        print('had space')
        time.sleep(1)
        return(np.nan)
    page = getPageODS(word)
    if page is None:
        print('no page at all')
        time.sleep(1)
        return(np.nan)
    page = BeautifulSoup(page)
    page = page.find_all("span", {"class":"lydskrift"})
    if not page:        
        time.sleep(1)
        print('no pron data')
        return(np.nan)
    page = page[0]
    rawPron = str(page.get_text())
    time.sleep(1)
    pron = parseRaw(rawPron)
    print(pron)
    print('------------------------------------------------------')
    return(pron)

# %%
def getPageODS(word): # query ODS instead of ODD
    urlWord = urllib.parse.quote(word)
    completeURL = 'https://ordnet.dk/ods/ordbog?query=' + urllib.parse.quote(word)
    print(completeURL)
    return(simple_get(completeURL))

# %%
forSecondScrape = notScraped['Orth'][pd.isnull(firstScrape)]
secondScrape = [getPronODS(word) for word in forSecondScrape]
# Out:
# skynde sig
# had space
# tre gange
# had space
# to gange
# had space
# par
# https://ordnet.dk/ods/ordbog?query=par
# nan
# ------------------------------------------------------
# få
# https://ordnet.dk/ods/ordbog?query=fa%CC%8A
# no page at all
# al
# https://ordnet.dk/ods/ordbog?query=al
# no pron data
# to
# https://ordnet.dk/ods/ordbog?query=to
# no pron data
# små
# https://ordnet.dk/ods/ordbog?query=sma%CC%8A
# no page at all
# måle
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Ale
# no page at all
# til-lukke
# https://ordnet.dk/ods/ordbog?query=til-lukke
# nan
# ------------------------------------------------------
# åbne
# https://ordnet.dk/ods/ordbog?query=a%CC%8Abne
# no page at all
# lukke op
# had space
# hobe op
# had space
# samle op
# had space
# stå
# https://ordnet.dk/ods/ordbog?query=sta%CC%8A
# no page at all
# ovenpå
# https://ordnet.dk/ods/ordbog?query=ovenpa%CC%8A
# no page at all
# ved siden af
# had space
# dele med
# had space
# låne
# https://ordnet.dk/ods/ordbog?query=la%CC%8Ane
# no page at all
# låne
# https://ordnet.dk/ods/ordbog?query=la%CC%8Ane
# no page at all
# slippe løs
# had space
# lede efter
# had space
# passe på
# had space
# give tilbage
# had space
# få
# https://ordnet.dk/ods/ordbog?query=fa%CC%8A
# no page at all
# åre
# https://ordnet.dk/ods/ordbog?query=a%CC%8Are
# no page at all
# flåde
# https://ordnet.dk/ods/ordbog?query=fla%CC%8Ade
# no page at all
# udlægger
# https://ordnet.dk/ods/ordbog?query=udl%C3%A6gger
# nan
# ------------------------------------------------------
# båd
# https://ordnet.dk/ods/ordbog?query=ba%CC%8Ad
# no page at all
# åg
# https://ordnet.dk/ods/ordbog?query=a%CC%8Ag
# no page at all
# bære under armen
# had space
# bære på hovedet
# had space
# bære på skulderen
# had space
# bære i hånden
# had space
# nærme sig
# had space
# nå
# https://ordnet.dk/ods/ordbog?query=na%CC%8A
# no page at all
# gå bort
# had space
# komme tilbage
# had space
# gå ud
# had space
# gå ned
# had space
# gå
# https://ordnet.dk/ods/ordbog?query=ga%CC%8A
# no page at all
# gå op
# had space
# gå
# https://ordnet.dk/ods/ordbog?query=ga%CC%8A
# no page at all
# sidde på hug
# had space
# stå op
# had space
# udhugge
# https://ordnet.dk/ods/ordbog?query=udhugge
# nan
# ------------------------------------------------------
# måtte
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Atte
# no page at all
# hænge op
# had space
# brede ud
# had space
# flå
# https://ordnet.dk/ods/ordbog?query=fla%CC%8A
# no page at all
# slå med næve
# had space
# slå
# https://ordnet.dk/ods/ordbog?query=sla%CC%8A
# no page at all
# løse op
# had space
# sukkerrør
# https://ordnet.dk/ods/ordbog?query=sukkerr%C3%B8r
# no pron data
# banantræ
# https://ordnet.dk/ods/ordbog?query=banantr%C3%A6
# no page at all
# palme-træ
# https://ordnet.dk/ods/ordbog?query=palme-tr%C3%A6
# no pron data
# gaffelgren
# https://ordnet.dk/ods/ordbog?query=gaffelgren
# no pron data
# træstamme
# https://ordnet.dk/ods/ordbog?query=tr%C3%A6stamme
# no pron data
# træstup
# https://ordnet.dk/ods/ordbog?query=tr%C3%A6stup
# no page at all
# vin-ranke
# https://ordnet.dk/ods/ordbog?query=vin-ranke
# no pron data
# vin-stok
# https://ordnet.dk/ods/ordbog?query=vin-stok
# no pron data
# slå
# https://ordnet.dk/ods/ordbog?query=sla%CC%8A
# no page at all
# så
# https://ordnet.dk/ods/ordbog?query=sa%CC%8A
# no page at all
# landmand
# https://ordnet.dk/ods/ordbog?query=landmand
# no pron data
# lertegl
# https://ordnet.dk/ods/ordbog?query=lertegl
# no page at all
# rygås
# https://ordnet.dk/ods/ordbog?query=ryga%CC%8As
# no page at all
# stråtag
# https://ordnet.dk/ods/ordbog?query=stra%CC%8Atag
# no page at all
# ildsted
# https://ordnet.dk/ods/ordbog?query=ildsted
# no pron data
# dør-klinke
# https://ordnet.dk/ods/ordbog?query=d%C3%B8r-klinke
# no pron data
# lås
# https://ordnet.dk/ods/ordbog?query=la%CC%8As
# no page at all
# dør-stolpe
# https://ordnet.dk/ods/ordbog?query=d%C3%B8r-stolpe
# no pron data
# forsamlingshus
# https://ordnet.dk/ods/ordbog?query=forsamlingshus
# no pron data
# gård
# https://ordnet.dk/ods/ordbog?query=ga%CC%8Ard
# no page at all
# havehus
# https://ordnet.dk/ods/ordbog?query=havehus
# no pron data
# barberkniv
# https://ordnet.dk/ods/ordbog?query=barberkniv
# no pron data
# håndklæde
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Andkl%C3%A6de
# no page at all
# hovedbeklædning
# https://ordnet.dk/ods/ordbog?query=hovedbekl%C3%A6dning
# no pron data
# ørenring
# https://ordnet.dk/ods/ordbog?query=%C3%B8renring
# no pron data
# halsbånd
# https://ordnet.dk/ods/ordbog?query=halsba%CC%8And
# no page at all
# armbånd
# https://ordnet.dk/ods/ordbog?query=armba%CC%8And
# no page at all
# nål
# https://ordnet.dk/ods/ordbog?query=na%CC%8Al
# no page at all
# mantel
# https://ordnet.dk/ods/ordbog?query=mantel
# nan
# ------------------------------------------------------
# tråd
# https://ordnet.dk/ods/ordbog?query=tra%CC%8Ad
# no page at all
# nål
# https://ordnet.dk/ods/ordbog?query=na%CC%8Al
# no page at all
# vævestol
# https://ordnet.dk/ods/ordbog?query=v%C3%A6vestol
# no pron data
# tage på
# had space
# æggeblomme
# https://ordnet.dk/ods/ordbog?query=%C3%A6ggeblomme
# no pron data
# rød pebber
# had space
# pebber
# https://ordnet.dk/ods/ordbog?query=pebber
# nan
# ------------------------------------------------------
# elte
# https://ordnet.dk/ods/ordbog?query=elte
# no page at all
# si
# https://ordnet.dk/ods/ordbog?query=si
# no pron data
# aftensmad
# https://ordnet.dk/ods/ordbog?query=aftensmad
# no pron data
# måltid
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Altid
# no page at all
# underkop
# https://ordnet.dk/ods/ordbog?query=underkop
# no pron data
# skål
# https://ordnet.dk/ods/ordbog?query=ska%CC%8Al
# no page at all
# lave mad
# had space
# rådden
# https://ordnet.dk/ods/ordbog?query=ra%CC%8Adden
# no page at all
# rå
# https://ordnet.dk/ods/ordbog?query=ra%CC%8A
# no page at all
# lægemiddel
# https://ordnet.dk/ods/ordbog?query=l%C3%A6gemiddel
# no pron data
# år
# https://ordnet.dk/ods/ordbog?query=a%CC%8Ar
# no page at all
# sår
# https://ordnet.dk/ods/ordbog?query=sa%CC%8Ar
# no page at all
# i live
# had space
# have samleje
# had space
# vågne
# https://ordnet.dk/ods/ordbog?query=va%CC%8Agne
# no page at all
# våge
# https://ordnet.dk/ods/ordbog?query=va%CC%8Age
# no page at all
# brække sig
# had space
# ånde
# https://ordnet.dk/ods/ordbog?query=a%CC%8Ande
# no page at all
# ånde
# https://ordnet.dk/ods/ordbog?query=a%CC%8Ande
# no page at all
# moderliv
# https://ordnet.dk/ods/ordbog?query=moderliv
# no pron data
# bagdel
# https://ordnet.dk/ods/ordbog?query=bagdel
# no pron data
# taille
# https://ordnet.dk/ods/ordbog?query=taille
# nan
# ------------------------------------------------------
# involde
# https://ordnet.dk/ods/ordbog?query=involde
# no page at all
# brystvorte
# https://ordnet.dk/ods/ordbog?query=brystvorte
# no pron data
# tå
# https://ordnet.dk/ods/ordbog?query=ta%CC%8A
# no page at all
# fodaftryk
# https://ordnet.dk/ods/ordbog?query=fodaftryk
# no pron data
# lår
# https://ordnet.dk/ods/ordbog?query=la%CC%8Ar
# no page at all
# fingernegl
# https://ordnet.dk/ods/ordbog?query=fingernegl
# no pron data
# håndflade
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Andflade
# no page at all
# hånd
# https://ordnet.dk/ods/ordbog?query=ha%CC%8And
# no page at all
# håndled
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Andled
# no page at all
# armhule
# https://ordnet.dk/ods/ordbog?query=armhule
# no pron data
# nøgleben
# https://ordnet.dk/ods/ordbog?query=n%C3%B8gleben
# no pron data
# skulderblad
# https://ordnet.dk/ods/ordbog?query=skulderblad
# no pron data
# ørevoks
# https://ordnet.dk/ods/ordbog?query=%C3%B8revoks
# no pron data
# øjenhår
# https://ordnet.dk/ods/ordbog?query=%C3%B8jenha%CC%8Ar
# no page at all
# øjelåg
# https://ordnet.dk/ods/ordbog?query=%C3%B8jela%CC%8Ag
# no page at all
# øjenbryn
# https://ordnet.dk/ods/ordbog?query=%C3%B8jenbryn
# nan
# ------------------------------------------------------
# hovedskal
# https://ordnet.dk/ods/ordbog?query=hovedskal
# no pron data
# hjerneskal
# https://ordnet.dk/ods/ordbog?query=hjerneskal
# no pron data
# åre
# https://ordnet.dk/ods/ordbog?query=a%CC%8Are
# no page at all
# skamhår
# https://ordnet.dk/ods/ordbog?query=skamha%CC%8Ar
# no page at all
# hår
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Ar
# no page at all
# hår
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Ar
# no page at all
# lysbille
# https://ordnet.dk/ods/ordbog?query=lysbille
# no pron data
# bikube
# https://ordnet.dk/ods/ordbog?query=bikube
# no pron data
# bi
# https://ordnet.dk/ods/ordbog?query=bi
# nan
# ------------------------------------------------------
# tusindben
# https://ordnet.dk/ods/ordbog?query=tusindben
# no pron data
# ferskvandsål
# https://ordnet.dk/ods/ordbog?query=ferskvandsa%CC%8Al
# no page at all
# fiskeskæl
# https://ordnet.dk/ods/ordbog?query=fiskesk%C3%A6l
# no pron data
# papagøje
# https://ordnet.dk/ods/ordbog?query=papag%C3%B8je
# no pron data
# måge
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Age
# no page at all
# gås
# https://ordnet.dk/ods/ordbog?query=ga%CC%8As
# no page at all
# moderfår
# https://ordnet.dk/ods/ordbog?query=moderfa%CC%8Ar
# no page at all
# får
# https://ordnet.dk/ods/ordbog?query=fa%CC%8Ar
# no page at all
# hun-
# https://ordnet.dk/ods/ordbog?query=hun-
# no pron data
# han-
# https://ordnet.dk/ods/ordbog?query=han-
# no pron data
# enkemand
# https://ordnet.dk/ods/ordbog?query=enkemand
# no pron data
# forældreløs
# https://ordnet.dk/ods/ordbog?query=for%C3%A6ldrel%C3%B8s
# no pron data
# søskendebarn
# https://ordnet.dk/ods/ordbog?query=s%C3%B8skendebarn
# no pron data
# sønnesøn
# https://ordnet.dk/ods/ordbog?query=s%C3%B8nnes%C3%B8n
# no pron data
# dattersøn
# https://ordnet.dk/ods/ordbog?query=datters%C3%B8n
# no pron data
# sønnedatter
# https://ordnet.dk/ods/ordbog?query=s%C3%B8nnedatter
# no pron data
# datterdatter
# https://ordnet.dk/ods/ordbog?query=datterdatter
# no pron data
# gammel kvinde
# had space
# gammel mand
# had space
# tvillinge
# https://ordnet.dk/ods/ordbog?query=tvillinge
# no page at all
# lillesøster
# https://ordnet.dk/ods/ordbog?query=lilles%C3%B8ster
# no pron data
# gift kvinde
# had space
# gift mand
# had space
# giftermål
# https://ordnet.dk/ods/ordbog?query=gifterma%CC%8Al
# no page at all
# gifte sig
# had space
# ægtemand
# https://ordnet.dk/ods/ordbog?query=%C3%A6gtemand
# no pron data
# ung kvinde
# had space
# ung mand
# had space
# trækul
# https://ordnet.dk/ods/ordbog?query=tr%C3%A6kul
# no pron data
# udryde
# https://ordnet.dk/ods/ordbog?query=udryde
# no page at all
# tåge
# https://ordnet.dk/ods/ordbog?query=ta%CC%8Age
# no page at all
# lynslag
# https://ordnet.dk/ods/ordbog?query=lynslag
# no pron data
# tordenkile
# https://ordnet.dk/ods/ordbog?query=tordenkile
# no pron data
# måne
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Ane
# no page at all
# jordskælv
# https://ordnet.dk/ods/ordbog?query=jordsk%C3%A6lv
# nan
# ------------------------------------------------------
# vandfald
# https://ordnet.dk/ods/ordbog?query=vandfald
# nan
# ------------------------------------------------------
# tidevande
# https://ordnet.dk/ods/ordbog?query=tidevande
# no pron data
# indsø
# https://ordnet.dk/ods/ordbog?query=inds%C3%B8
# no pron data
# daggry
# https://ordnet.dk/ods/ordbog?query=daggry
# no pron data
# i dag
# had space
# i morgen
# had space
# i overmorgen
# had space
# i går
# had space
# i forgårs
# had space
# måned
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Aned
# no page at all
# år
# https://ordnet.dk/ods/ordbog?query=a%CC%8Ar
# no page at all
# forår
# https://ordnet.dk/ods/ordbog?query=fora%CC%8Ar
# no page at all
# efterår
# https://ordnet.dk/ods/ordbog?query=eftera%CC%8Ar
# no page at all
# årstid
# https://ordnet.dk/ods/ordbog?query=a%CC%8Arstid
# no page at all
# se på
# had space
# blå
# https://ordnet.dk/ods/ordbog?query=bla%CC%8A
# no page at all
# røre ved
# had space
# hård
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Ard
# no page at all
# våd
# https://ordnet.dk/ods/ordbog?query=va%CC%8Ad
# no page at all
# ånd
# https://ordnet.dk/ods/ordbog?query=a%CC%8And
# no page at all
# tåre
# https://ordnet.dk/ods/ordbog?query=ta%CC%8Are
# no page at all
# håb
# https://ordnet.dk/ods/ordbog?query=ha%CC%8Ab
# no page at all
# dårlig
# https://ordnet.dk/ods/ordbog?query=da%CC%8Arlig
# no page at all
# grådig
# https://ordnet.dk/ods/ordbog?query=gra%CC%8Adig
# no page at all
# ånd
# https://ordnet.dk/ods/ordbog?query=a%CC%8And
# no page at all
# forstå
# https://ordnet.dk/ods/ordbog?query=forsta%CC%8A
# no page at all
# tåbelig
# https://ordnet.dk/ods/ordbog?query=ta%CC%8Abelig
# no page at all
# årsag
# https://ordnet.dk/ods/ordbog?query=a%CC%8Arsag
# no page at all
# forråde
# https://ordnet.dk/ods/ordbog?query=forra%CC%8Ade
# no page at all
# måde
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Ade
# no page at all
# hvordan?
# https://ordnet.dk/ods/ordbog?query=hvordan%3F
# no page at all
# hvor mange?
# had space
# hvor meget?
# had space
# hvad?
# https://ordnet.dk/ods/ordbog?query=hvad%3F
# no page at all
# hvornår?
# https://ordnet.dk/ods/ordbog?query=hvorna%CC%8Ar%3F
# no page at all
# hvilken?
# https://ordnet.dk/ods/ordbog?query=hvilken%3F
# no page at all
# hvem?
# https://ordnet.dk/ods/ordbog?query=hvem%3F
# no page at all
# hvorfor?
# https://ordnet.dk/ods/ordbog?query=hvorfor%3F
# nan
# ------------------------------------------------------
# råbe
# https://ordnet.dk/ods/ordbog?query=ra%CC%8Abe
# no page at all
# tale (holde en)
# had space
# mål
# https://ordnet.dk/ods/ordbog?query=ma%CC%8Al
# no page at all
# tilstå
# https://ordnet.dk/ods/ordbog?query=tilsta%CC%8A
# no page at all
# afslå
# https://ordnet.dk/ods/ordbog?query=afsla%CC%8A
# no page at all
# vægre sig ved
# had space
# rasle-
# https://ordnet.dk/ods/ordbog?query=rasle-
# no pron data
# fosterland
# https://ordnet.dk/ods/ordbog?query=fosterland
# no pron data
# adelsmand
# https://ordnet.dk/ods/ordbog?query=adelsmand
# no pron data
# slås
# https://ordnet.dk/ods/ordbog?query=sla%CC%8As
# no page at all
# armé
# https://ordnet.dk/ods/ordbog?query=arme%CC%81
# no page at all
# våben
# https://ordnet.dk/ods/ordbog?query=va%CC%8Aben
# no page at all
# tårn
# https://ordnet.dk/ods/ordbog?query=ta%CC%8Arn
# no page at all
# fiskekrog
# https://ordnet.dk/ods/ordbog?query=fiskekrog
# no pron data
# fiskenet
# https://ordnet.dk/ods/ordbog?query=fiskenet
# no page at all
# lokkemad
# https://ordnet.dk/ods/ordbog?query=lokkemad
# no pron data
# ramme forbi
# had space
# ond ånd
# had space

# %%
notScraped.to_csv('backupSecondScrape.csv')

# %%
words = pd.read_csv('danishOrthPhon.csv')

# %%
for word in notScraped['Orth']:
    print(word)
    index1 = pd.Index(list(words['Orth'])).get_loc(word)
    index2 = pd.Index(list(notScraped['Orth'])).get_loc(word)
    if type(index1) is int:
        words.iloc[index1, 2] = notScraped.iloc[index2, 2]
        print(words.iloc[index1])
# Out:
# skynde sig
# Unnamed: 0            14
# Orth          skynde sig
# Phon                 NaN
# Name: 14, dtype: object
# tre gange
# Unnamed: 0           28
# Orth          tre gange
# Phon                NaN
# Name: 28, dtype: object
# to gange
# Unnamed: 0          30
# Orth          to gange
# Phon               NaN
# Name: 30, dtype: object
# par
# Unnamed: 0     31
# Orth          par
# Phon          NaN
# Name: 31, dtype: object
# få
# al
# Unnamed: 0     54
# Orth           al
# Phon          NaN
# Name: 54, dtype: object
# to
# Unnamed: 0     70
# Orth           to
# Phon          NaN
# Name: 70, dtype: object
# små
# Unnamed: 0     110
# Orth          små
# Phon           NaN
# Name: 110, dtype: object
# måle
# Unnamed: 0      113
# Orth          måle
# Phon            NaN
# Name: 113, dtype: object
# til-lukke
# Unnamed: 0          140
# Orth          til-lukke
# Phon                NaN
# Name: 140, dtype: object
# åbne
# Unnamed: 0      142
# Orth          åbne
# Phon            NaN
# Name: 142, dtype: object
# lukke op
# Unnamed: 0         143
# Orth          lukke op
# Phon               NaN
# Name: 143, dtype: object
# hobe op
# Unnamed: 0        149
# Orth          hobe op
# Phon              NaN
# Name: 149, dtype: object
# samle op
# Unnamed: 0         150
# Orth          samle op
# Phon               NaN
# Name: 150, dtype: object
# stå
# Unnamed: 0     154
# Orth          stå
# Phon           NaN
# Name: 154, dtype: object
# ovenpå
# Unnamed: 0        163
# Orth          ovenpå
# Phon              NaN
# Name: 163, dtype: object
# ved siden af
# Unnamed: 0             170
# Orth          ved siden af
# Phon                   NaN
# Name: 170, dtype: object
# dele med
# Unnamed: 0         174
# Orth          dele med
# Phon               NaN
# Name: 174, dtype: object
# låne
# låne
# slippe løs
# Unnamed: 0           205
# Orth          slippe løs
# Phon                 NaN
# Name: 205, dtype: object
# lede efter
# Unnamed: 0           210
# Orth          lede efter
# Phon                 NaN
# Name: 210, dtype: object
# passe på
# Unnamed: 0          217
# Orth          passe på
# Phon                NaN
# Name: 217, dtype: object
# give tilbage
# Unnamed: 0             218
# Orth          give tilbage
# Phon                   NaN
# Name: 218, dtype: object
# få
# åre
# flåde
# Unnamed: 0       239
# Orth          flåde
# Phon             NaN
# Name: 239, dtype: object
# udlægger
# Unnamed: 0         240
# Orth          udlægger
# Phon               NaN
# Name: 240, dtype: object
# båd
# Unnamed: 0     242
# Orth          båd
# Phon           NaN
# Name: 242, dtype: object
# åg
# Unnamed: 0    244
# Orth          åg
# Phon          NaN
# Name: 244, dtype: object
# bære under armen
# Unnamed: 0                 259
# Orth          bære under armen
# Phon                       NaN
# Name: 259, dtype: object
# bære på hovedet
# Unnamed: 0                 260
# Orth          bære på hovedet
# Phon                       NaN
# Name: 260, dtype: object
# bære på skulderen
# Unnamed: 0                   261
# Orth          bære på skulderen
# Phon                         NaN
# Name: 261, dtype: object
# bære i hånden
# Unnamed: 0               262
# Orth          bære i hånden
# Phon                     NaN
# Name: 262, dtype: object
# nærme sig
# Unnamed: 0          265
# Orth          nærme sig
# Phon                NaN
# Name: 265, dtype: object
# nå
# Unnamed: 0    267
# Orth          nå
# Phon          NaN
# Name: 267, dtype: object
# gå bort
# Unnamed: 0         273
# Orth          gå bort
# Phon               NaN
# Name: 273, dtype: object
# komme tilbage
# Unnamed: 0              274
# Orth          komme tilbage
# Phon                    NaN
# Name: 274, dtype: object
# gå ud
# Unnamed: 0       276
# Orth          gå ud
# Phon             NaN
# Name: 276, dtype: object
# gå ned
# Unnamed: 0        277
# Orth          gå ned
# Phon              NaN
# Name: 277, dtype: object
# gå
# gå op
# Unnamed: 0       281
# Orth          gå op
# Phon             NaN
# Name: 281, dtype: object
# gå
# sidde på hug
# Unnamed: 0              291
# Orth          sidde på hug
# Phon                    NaN
# Name: 291, dtype: object
# stå op
# Unnamed: 0        313
# Orth          stå op
# Phon              NaN
# Name: 313, dtype: object
# udhugge
# Unnamed: 0        331
# Orth          udhugge
# Phon              NaN
# Name: 331, dtype: object
# måtte
# Unnamed: 0       335
# Orth          måtte
# Phon             NaN
# Name: 335, dtype: object
# hænge op
# Unnamed: 0         376
# Orth          hænge op
# Phon               NaN
# Name: 376, dtype: object
# brede ud
# Unnamed: 0         377
# Orth          brede ud
# Phon               NaN
# Name: 377, dtype: object
# flå
# Unnamed: 0     384
# Orth          flå
# Phon           NaN
# Name: 384, dtype: object
# slå med næve
# Unnamed: 0              401
# Orth          slå med næve
# Phon                    NaN
# Name: 401, dtype: object
# slå
# løse op
# Unnamed: 0        409
# Orth          løse op
# Phon              NaN
# Name: 409, dtype: object
# sukkerrør
# Unnamed: 0          417
# Orth          sukkerrør
# Phon                NaN
# Name: 417, dtype: object
# banantræ
# Unnamed: 0         422
# Orth          banantræ
# Phon               NaN
# Name: 422, dtype: object
# palme-træ
# Unnamed: 0          425
# Orth          palme-træ
# Phon                NaN
# Name: 425, dtype: object
# gaffelgren
# Unnamed: 0           428
# Orth          gaffelgren
# Phon                 NaN
# Name: 428, dtype: object
# træstamme
# Unnamed: 0          429
# Orth          træstamme
# Phon                NaN
# Name: 429, dtype: object
# træstup
# Unnamed: 0        430
# Orth          træstup
# Phon              NaN
# Name: 430, dtype: object
# vin-ranke
# Unnamed: 0          434
# Orth          vin-ranke
# Phon                NaN
# Name: 434, dtype: object
# vin-stok
# Unnamed: 0         435
# Orth          vin-stok
# Phon               NaN
# Name: 435, dtype: object
# slå
# så
# Unnamed: 0    469
# Orth          så
# Phon          NaN
# Name: 469, dtype: object
# spade
# Unnamed: 0        475
# Orth            spade
# Phon          ˈsbæːðə
# Name: 475, dtype: object
# landmand
# Unnamed: 0         486
# Orth          landmand
# Phon               NaN
# Name: 486, dtype: object
# lertegl
# Unnamed: 0        488
# Orth          lertegl
# Phon              NaN
# Name: 488, dtype: object
# rygås
# Unnamed: 0       498
# Orth          rygås
# Phon             NaN
# Name: 498, dtype: object
# stråtag
# Unnamed: 0         499
# Orth          stråtag
# Phon               NaN
# Name: 499, dtype: object
# ildsted
# Unnamed: 0        513
# Orth          ildsted
# Phon              NaN
# Name: 513, dtype: object
# dør-klinke
# Unnamed: 0           519
# Orth          dør-klinke
# Phon                 NaN
# Name: 519, dtype: object
# lås
# Unnamed: 0     520
# Orth          lås
# Phon           NaN
# Name: 520, dtype: object
# dør-stolpe
# Unnamed: 0           521
# Orth          dør-stolpe
# Phon                 NaN
# Name: 521, dtype: object
# forsamlingshus
# Unnamed: 0               525
# Orth          forsamlingshus
# Phon                     NaN
# Name: 525, dtype: object
# gård
# Unnamed: 0      526
# Orth          gård
# Phon            NaN
# Name: 526, dtype: object
# havehus
# Unnamed: 0        528
# Orth          havehus
# Phon              NaN
# Name: 528, dtype: object
# barberkniv
# Unnamed: 0           535
# Orth          barberkniv
# Phon                 NaN
# Name: 535, dtype: object
# håndklæde
# Unnamed: 0           539
# Orth          håndklæde
# Phon                 NaN
# Name: 539, dtype: object
# hovedbeklædning
# Unnamed: 0                542
# Orth          hovedbeklædning
# Phon                      NaN
# Name: 542, dtype: object
# ørenring
# Unnamed: 0         543
# Orth          ørenring
# Phon               NaN
# Name: 543, dtype: object
# halsbånd
# Unnamed: 0          545
# Orth          halsbånd
# Phon                NaN
# Name: 545, dtype: object
# armbånd
# Unnamed: 0         546
# Orth          armbånd
# Phon               NaN
# Name: 546, dtype: object
# nål
# mantel
# Unnamed: 0       574
# Orth          mantel
# Phon             NaN
# Name: 574, dtype: object
# tråd
# Unnamed: 0      575
# Orth          tråd
# Phon            NaN
# Name: 575, dtype: object
# nål
# vævestol
# Unnamed: 0         579
# Orth          vævestol
# Phon               NaN
# Name: 579, dtype: object
# tage på
# Unnamed: 0         597
# Orth          tage på
# Phon               NaN
# Name: 597, dtype: object
# æggeblomme
# Unnamed: 0           598
# Orth          æggeblomme
# Phon                 NaN
# Name: 598, dtype: object
# rød pebber
# Unnamed: 0           610
# Orth          rød pebber
# Phon                 NaN
# Name: 610, dtype: object
# pebber
# Unnamed: 0       611
# Orth          pebber
# Phon             NaN
# Name: 611, dtype: object
# elte
# Unnamed: 0     633
# Orth          elte
# Phon           NaN
# Name: 633, dtype: object
# si
# Unnamed: 0    638
# Orth           si
# Phon          NaN
# Name: 638, dtype: object
# aftensmad
# Unnamed: 0          641
# Orth          aftensmad
# Phon                NaN
# Name: 641, dtype: object
# måltid
# Unnamed: 0        645
# Orth          måltid
# Phon              NaN
# Name: 645, dtype: object
# underkop
# Unnamed: 0         650
# Orth          underkop
# Phon               NaN
# Name: 650, dtype: object
# skål
# Unnamed: 0      652
# Orth          skål
# Phon            NaN
# Name: 652, dtype: object
# lave mad
# Unnamed: 0         665
# Orth          lave mad
# Phon               NaN
# Name: 665, dtype: object
# rådden
# Unnamed: 0        675
# Orth          rådden
# Phon              NaN
# Name: 675, dtype: object
# rå
# Unnamed: 0    678
# Orth          rå
# Phon          NaN
# Name: 678, dtype: object
# lægemiddel
# Unnamed: 0           699
# Orth          lægemiddel
# Phon                 NaN
# Name: 699, dtype: object
# år
# sår
# Unnamed: 0     710
# Orth          sår
# Phon           NaN
# Name: 710, dtype: object
# i live
# Unnamed: 0       733
# Orth          i live
# Phon             NaN
# Name: 733, dtype: object
# have samleje
# Unnamed: 0             742
# Orth          have samleje
# Phon                   NaN
# Name: 742, dtype: object
# tisse
# Unnamed: 0      746
# Orth          tisse
# Phon          ˈtisə
# Name: 746, dtype: object
# vågne
# Unnamed: 0       751
# Orth          vågne
# Phon             NaN
# Name: 751, dtype: object
# våge
# Unnamed: 0      752
# Orth          våge
# Phon            NaN
# Name: 752, dtype: object
# brække sig
# Unnamed: 0           759
# Orth          brække sig
# Phon                 NaN
# Name: 759, dtype: object
# hoste
# Unnamed: 0        763
# Orth            hoste
# Phon          ˈhoːsdə
# Name: 763, dtype: object
# hik
# Unnamed: 0     764
# Orth           hik
# Phon          ˈheg
# Name: 764, dtype: object
# gabe
# Unnamed: 0       765
# Orth            gabe
# Phon          ˈgæːbə
# Name: 765, dtype: object
# ånde
# ånde
# moderliv
# Unnamed: 0         770
# Orth          moderliv
# Phon               NaN
# Name: 770, dtype: object
# bagdel
# Unnamed: 0       771
# Orth          bagdel
# Phon             NaN
# Name: 771, dtype: object
# taille
# Unnamed: 0       773
# Orth          taille
# Phon             NaN
# Name: 773, dtype: object
# involde
# Unnamed: 0        774
# Orth          involde
# Phon              NaN
# Name: 774, dtype: object
# brystvorte
# Unnamed: 0           783
# Orth          brystvorte
# Phon                 NaN
# Name: 783, dtype: object
# tå
# Unnamed: 0    789
# Orth          tå
# Phon          NaN
# Name: 789, dtype: object
# fodaftryk
# Unnamed: 0          790
# Orth          fodaftryk
# Phon                NaN
# Name: 790, dtype: object
# lår
# Unnamed: 0     796
# Orth          lår
# Phon           NaN
# Name: 796, dtype: object
# fingernegl
# Unnamed: 0           799
# Orth          fingernegl
# Phon                 NaN
# Name: 799, dtype: object
# håndflade
# Unnamed: 0           802
# Orth          håndflade
# Phon                 NaN
# Name: 802, dtype: object
# hånd
# Unnamed: 0      803
# Orth          hånd
# Phon            NaN
# Name: 803, dtype: object
# håndled
# Unnamed: 0         804
# Orth          håndled
# Phon               NaN
# Name: 804, dtype: object
# armhule
# Unnamed: 0        806
# Orth          armhule
# Phon              NaN
# Name: 806, dtype: object
# nøgleben
# Unnamed: 0         808
# Orth          nøgleben
# Phon               NaN
# Name: 808, dtype: object
# skulderblad
# Unnamed: 0            809
# Orth          skulderblad
# Phon                  NaN
# Name: 809, dtype: object
# ørevoks
# Unnamed: 0        825
# Orth          ørevoks
# Phon              NaN
# Name: 825, dtype: object
# øjenhår
# Unnamed: 0         829
# Orth          øjenhår
# Phon               NaN
# Name: 829, dtype: object
# øjelåg
# Unnamed: 0        830
# Orth          øjelåg
# Phon              NaN
# Name: 830, dtype: object
# øjenbryn
# Unnamed: 0         831
# Orth          øjenbryn
# Phon               NaN
# Name: 831, dtype: object
# hovedskal
# Unnamed: 0          840
# Orth          hovedskal
# Phon                NaN
# Name: 840, dtype: object
# hjerneskal
# Unnamed: 0           841
# Orth          hjerneskal
# Phon                 NaN
# Name: 841, dtype: object
# åre
# skamhår
# Unnamed: 0         854
# Orth          skamhår
# Phon               NaN
# Name: 854, dtype: object
# hår
# hår
# lysbille
# Unnamed: 0         870
# Orth          lysbille
# Phon               NaN
# Name: 870, dtype: object
# bikube
# Unnamed: 0       878
# Orth          bikube
# Phon             NaN
# Name: 878, dtype: object
# bi
# Unnamed: 0    880
# Orth           bi
# Phon          NaN
# Name: 880, dtype: object
# tusindben
# Unnamed: 0          886
# Orth          tusindben
# Phon                NaN
# Name: 886, dtype: object
# ferskvandsål
# Unnamed: 0              899
# Orth          ferskvandsål
# Phon                    NaN
# Name: 899, dtype: object
# fiskeskæl
# Unnamed: 0          907
# Orth          fiskeskæl
# Phon                NaN
# Name: 907, dtype: object
# papagøje
# Unnamed: 0         919
# Orth          papagøje
# Phon               NaN
# Name: 919, dtype: object
# måge
# Unnamed: 0      924
# Orth          måge
# Phon            NaN
# Name: 924, dtype: object
# gås
# Unnamed: 0     929
# Orth          gås
# Phon           NaN
# Name: 929, dtype: object
# moderfår
# Unnamed: 0          948
# Orth          moderfår
# Phon                NaN
# Name: 948, dtype: object
# får
# Unnamed: 0     950
# Orth          får
# Phon           NaN
# Name: 950, dtype: object
# kalv
# Unnamed: 0       951
# Orth            kalv
# Phon          ˈkalˀv
# Name: 951, dtype: object
# hun-
# Unnamed: 0     960
# Orth          hun-
# Phon           NaN
# Name: 960, dtype: object
# han-
# Unnamed: 0     961
# Orth          han-
# Phon           NaN
# Name: 961, dtype: object
# enkemand
# Unnamed: 0         973
# Orth          enkemand
# Phon               NaN
# Name: 973, dtype: object
# forældreløs
# Unnamed: 0            975
# Orth          forældreløs
# Phon                  NaN
# Name: 975, dtype: object
# søskendebarn
# Unnamed: 0             992
# Orth          søskendebarn
# Phon                   NaN
# Name: 992, dtype: object
# sønnesøn
# Unnamed: 0        1001
# Orth          sønnesøn
# Phon               NaN
# Name: 1001, dtype: object
# dattersøn
# Unnamed: 0         1002
# Orth          dattersøn
# Phon                NaN
# Name: 1002, dtype: object
# sønnedatter
# Unnamed: 0           1003
# Orth          sønnedatter
# Phon                  NaN
# Name: 1003, dtype: object
# datterdatter
# Unnamed: 0            1004
# Orth          datterdatter
# Phon                   NaN
# Name: 1004, dtype: object
# gammel kvinde
# Unnamed: 0             1005
# Orth          gammel kvinde
# Phon                    NaN
# Name: 1005, dtype: object
# gammel mand
# Unnamed: 0           1007
# Orth          gammel mand
# Phon                  NaN
# Name: 1007, dtype: object
# tvillinge
# Unnamed: 0         1009
# Orth          tvillinge
# Phon                NaN
# Name: 1009, dtype: object
# lillesøster
# Unnamed: 0           1011
# Orth          lillesøster
# Phon                  NaN
# Name: 1011, dtype: object
# gift kvinde
# Unnamed: 0           1021
# Orth          gift kvinde
# Phon                  NaN
# Name: 1021, dtype: object
# gift mand
# Unnamed: 0         1022
# Orth          gift mand
# Phon                NaN
# Name: 1022, dtype: object
# giftermål
# Unnamed: 0          1029
# Orth          giftermål
# Phon                 NaN
# Name: 1029, dtype: object
# gifte sig
# Unnamed: 0         1031
# Orth          gifte sig
# Phon                NaN
# Name: 1031, dtype: object
# ægtemand
# Unnamed: 0        1035
# Orth          ægtemand
# Phon               NaN
# Name: 1035, dtype: object
# ung kvinde
# Unnamed: 0          1038
# Orth          ung kvinde
# Phon                 NaN
# Name: 1038, dtype: object
# ung mand
# Unnamed: 0        1040
# Orth          ung mand
# Phon               NaN
# Name: 1040, dtype: object
# trækul
# Unnamed: 0      1047
# Orth          trækul
# Phon             NaN
# Name: 1047, dtype: object
# udryde
# Unnamed: 0      1050
# Orth          udryde
# Phon             NaN
# Name: 1050, dtype: object
# tåge
# Unnamed: 0     1063
# Orth          tåge
# Phon            NaN
# Name: 1063, dtype: object
# lynslag
# Unnamed: 0       1074
# Orth          lynslag
# Phon              NaN
# Name: 1074, dtype: object
# tordenkile
# Unnamed: 0          1075
# Orth          tordenkile
# Phon                 NaN
# Name: 1075, dtype: object
# måne
# Unnamed: 0     1078
# Orth          måne
# Phon            NaN
# Name: 1078, dtype: object
# jordskælv
# Unnamed: 0         1081
# Orth          jordskælv
# Phon                NaN
# Name: 1081, dtype: object
# vandfald
# Unnamed: 0        1087
# Orth          vandfald
# Phon               NaN
# Name: 1087, dtype: object
# tidevande
# Unnamed: 0         1097
# Orth          tidevande
# Phon                NaN
# Name: 1097, dtype: object
# indsø
# Unnamed: 0     1104
# Orth          indsø
# Phon            NaN
# Name: 1104, dtype: object
# daggry
# Unnamed: 0      1142
# Orth          daggry
# Phon             NaN
# Name: 1142, dtype: object
# i dag
# Unnamed: 0     1147
# Orth          i dag
# Phon            NaN
# Name: 1147, dtype: object
# i morgen
# Unnamed: 0        1148
# Orth          i morgen
# Phon               NaN
# Name: 1148, dtype: object
# i overmorgen
# Unnamed: 0            1149
# Orth          i overmorgen
# Phon                   NaN
# Name: 1149, dtype: object
# i går
# Unnamed: 0      1150
# Orth          i går
# Phon             NaN
# Name: 1150, dtype: object
# i forgårs
# Unnamed: 0          1151
# Orth          i forgårs
# Phon                 NaN
# Name: 1151, dtype: object
# måned
# Unnamed: 0      1163
# Orth          måned
# Phon             NaN
# Name: 1163, dtype: object
# år
# forår
# Unnamed: 0      1166
# Orth          forår
# Phon             NaN
# Name: 1166, dtype: object
# efterår
# Unnamed: 0        1168
# Orth          efterår
# Phon               NaN
# Name: 1168, dtype: object
# årstid
# Unnamed: 0       1169
# Orth          årstid
# Phon              NaN
# Name: 1169, dtype: object
# se på
# Unnamed: 0      1188
# Orth          se på
# Phon             NaN
# Name: 1188, dtype: object
# blå
# Unnamed: 0    1201
# Orth          blå
# Phon           NaN
# Name: 1201, dtype: object
# røre ved
# Unnamed: 0        1205
# Orth          røre ved
# Phon               NaN
# Name: 1205, dtype: object
# hård
# Unnamed: 0     1208
# Orth          hård
# Phon            NaN
# Name: 1208, dtype: object
# våd
# Unnamed: 0    1220
# Orth          våd
# Phon           NaN
# Name: 1220, dtype: object
# ånd
# tåre
# Unnamed: 0     1254
# Orth          tåre
# Phon            NaN
# Name: 1254, dtype: object
# tapper
# Unnamed: 0      1265
# Orth          tapper
# Phon           ˈtɑbʌ
# Name: 1265, dtype: object
# håb
# Unnamed: 0    1272
# Orth          håb
# Phon           NaN
# Name: 1272, dtype: object
# dårlig
# Unnamed: 0       1280
# Orth          dårlig
# Phon              NaN
# Name: 1280, dtype: object
# grådig
# Unnamed: 0       1295
# Orth          grådig
# Phon              NaN
# Name: 1295, dtype: object
# ånd
# forstå
# Unnamed: 0       1304
# Orth          forstå
# Phon              NaN
# Name: 1304, dtype: object
# tåbelig
# Unnamed: 0        1313
# Orth          tåbelig
# Phon               NaN
# Name: 1313, dtype: object
# årsag
# Unnamed: 0      1338
# Orth          årsag
# Phon             NaN
# Name: 1338, dtype: object
# forråde
# Unnamed: 0        1341
# Orth          forråde
# Phon               NaN
# Name: 1341, dtype: object
# måde
# Unnamed: 0     1346
# Orth          måde
# Phon            NaN
# Name: 1346, dtype: object
# hvordan?
# Unnamed: 0        1353
# Orth          hvordan?
# Phon               NaN
# Name: 1353, dtype: object
# hvor mange?
# Unnamed: 0           1354
# Orth          hvor mange?
# Phon                  NaN
# Name: 1354, dtype: object
# hvor meget?
# Unnamed: 0           1355
# Orth          hvor meget?
# Phon                  NaN
# Name: 1355, dtype: object
# hvad?
# Unnamed: 0     1356
# Orth          hvad?
# Phon            NaN
# Name: 1356, dtype: object
# hvornår?
# Unnamed: 0         1357
# Orth          hvornår?
# Phon                NaN
# Name: 1357, dtype: object
# hvilken?
# Unnamed: 0        1359
# Orth          hvilken?
# Phon               NaN
# Name: 1359, dtype: object
# hvem?
# Unnamed: 0     1360
# Orth          hvem?
# Phon            NaN
# Name: 1360, dtype: object
# hvorfor?
# Unnamed: 0        1361
# Orth          hvorfor?
# Phon               NaN
# Name: 1361, dtype: object
# råbe
# Unnamed: 0     1365
# Orth          råbe
# Phon            NaN
# Name: 1365, dtype: object
# tale (holde en)
# Unnamed: 0               1376
# Orth          tale (holde en)
# Phon                      NaN
# Name: 1376, dtype: object
# mål
# Unnamed: 0    1379
# Orth          mål
# Phon           NaN
# Name: 1379, dtype: object
# tilstå
# Unnamed: 0       1384
# Orth          tilstå
# Phon              NaN
# Name: 1384, dtype: object
# afslå
# Unnamed: 0      1391
# Orth          afslå
# Phon             NaN
# Name: 1391, dtype: object
# vægre sig ved
# Unnamed: 0             1392
# Orth          vægre sig ved
# Phon                    NaN
# Name: 1392, dtype: object
# rasle-
# Unnamed: 0      1411
# Orth          rasle-
# Phon             NaN
# Name: 1411, dtype: object
# fosterland
# Unnamed: 0          1414
# Orth          fosterland
# Phon                 NaN
# Name: 1414, dtype: object
# adelsmand
# Unnamed: 0         1429
# Orth          adelsmand
# Phon                NaN
# Name: 1429, dtype: object
# fremmed
# Unnamed: 0       1443
# Orth          fremmed
# Phon          ˈfʁaməð
# Name: 1443, dtype: object
# hindre
# Unnamed: 0       1447
# Orth           hindre
# Phon          ˈhendʁʌ
# Name: 1447, dtype: object
# for-hindre
# Unnamed: 0          1448
# Orth          for-hindre
# Phon          fʌˈhenˀdʁʌ
# Name: 1448, dtype: object
# strid
# Unnamed: 0       1451
# Orth            strid
# Phon          ˈsdʁiðˀ
# Name: 1451, dtype: object
# slås
# Unnamed: 0     1456
# Orth          slås
# Phon            NaN
# Name: 1456, dtype: object
# armé
# Unnamed: 0     1462
# Orth          armé
# Phon            NaN
# Name: 1462, dtype: object
# våben
# Unnamed: 0      1464
# Orth          våben
# Phon             NaN
# Name: 1464, dtype: object
# stridsøkse
# Unnamed: 0          1466
# Orth          stridsøkse
# Phon            ˈsdʁiðs-
# Name: 1466, dtype: object
# sværd
# Unnamed: 0       1472
# Orth            sværd
# Phon          ˈsvεˀɐ̯
# Name: 1472, dtype: object
# rustning
# Unnamed: 0        1476
# Orth          rustning
# Phon          ˈʁɔsdneŋ
# Name: 1476, dtype: object
# tårn
# Unnamed: 0     1481
# Orth          tårn
# Phon            NaN
# Name: 1481, dtype: object
# retræte
# Unnamed: 0         1486
# Orth            retræte
# Phon          ʁεˈtʁεːdə
# Name: 1486, dtype: object
# rov
# Unnamed: 0    1491
# Orth           rov
# Phon          ˈʁɒw
# Name: 1491, dtype: object
# fiskekrog
# Unnamed: 0         1494
# Orth          fiskekrog
# Phon                NaN
# Name: 1494, dtype: object
# fiskenet
# Unnamed: 0        1496
# Orth          fiskenet
# Phon               NaN
# Name: 1496, dtype: object
# lokkemad
# Unnamed: 0        1497
# Orth          lokkemad
# Phon               NaN
# Name: 1497, dtype: object
# ramme forbi
# Unnamed: 0           1500
# Orth          ramme forbi
# Phon                  NaN
# Name: 1500, dtype: object
# anklage
# Unnamed: 0          1513
# Orth             anklage
# Phon          ˈanˌklæːjə
# Name: 1513, dtype: object
# straf
# Unnamed: 0      1521
# Orth           straf
# Phon          ˈsdʁɑf
# Name: 1521, dtype: object
# mordbrand
# Unnamed: 0         1527
# Orth          mordbrand
# Phon             ˈmoɐ̯-
# Name: 1527, dtype: object
# Gud
# Unnamed: 0    1532
# Orth           Gud
# Phon          ˈguð
# Name: 1532, dtype: object
# ond ånd
# Unnamed: 0        1546
# Orth          ond ånd
# Phon               NaN
# Name: 1546, dtype: object
# troldkvinde
# Unnamed: 0           1551
# Orth          troldkvinde
# Phon               ˈtʁʌl-
# Name: 1551, dtype: object
# fe
# Unnamed: 0    1552
# Orth            fe
# Phon          ˈfeˀ
# Name: 1552, dtype: object

# %%
words.to_csv('danishOrthPhon.csv', encoding = 'utf-8')
